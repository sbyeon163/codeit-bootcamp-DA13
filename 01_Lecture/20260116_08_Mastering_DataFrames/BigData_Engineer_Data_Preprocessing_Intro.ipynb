# %% [markdown]
# # Q1

# %% [markdown]
# Q. 다음은 보스턴 집 값 데이터이다. 각 행은 지역구별 집 값과 관련된 정보를 담고 있다.
#
# data : https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e2_p1_1.csv

# %% [markdown]
# ## 1-1

# %% [markdown]
# Q. 주어진 데이터에서 CRIM 값이 가장 큰 10개의 지역을 구하고, 10개 지역의 CRIM 값을 그 중 가장 작은 값으로 대체하시오. 그리고, AGE 컬럼 값이 80 이상인 대체된 CRIM 평균값을 구하시오.

# %% [markdown]
# - 답) 5.759386625

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np

# %%
# 데이터 불러오기
data = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e2_p1_1.csv')

# %%
# 주어진 데이터에서 CRIM 값이 가장 큰 10개의 지역을 구하고,
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666.0
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666.0
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666.0
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666.0
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666.0
# 404  41.5292  0.0   18.1     0  0.693  5.531   85.4  1.6074   24  666.0
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666.0
# 427  37.6619  0.0   18.1     0  0.679  6.202   78.7  1.8629   24  666.0
# 413  28.6558  0.0   18.1     0  0.597  5.155  100.0  1.5894   24  666.0
# 417  25.9406  0.0   18.1     0  0.679  5.304   89.1  1.6475   24  666.0
#
#      PTRATIO       B  LSTAT  MEDV
# 380     20.2  396.90  17.21  10.4
# 418     20.2   16.45  20.62   8.8
# 405     20.2  384.97  22.98   5.0
# 410     20.2    2.60  10.11  15.0
# ...

# %%
# 10개 지역의 CRIM 값을 그 중 가장 작은 값으로 대체하시오.

# %%
# 그리고, AGE 컬럼 값이 80 이상인 대체된 CRIM 평균값을 구하시오.

# %% [markdown]
# ## 1-2

# %% [markdown]
# Q. 1-1에서 사용한 데이터에서 RM 중앙값으로 해당 컬럼의 결측치를 대체하시오. 그리고, 해당 컬럼의 결측치 대치 전후의 표준편차 차이의 절댓값을 소수점 이하 셋째짜리까지 구하시오.

# %% [markdown]
# - 답) 0.027

# %%
# 사용한 데이터에서 RM 중앙값으로 해당 컬럼의 결측치를 대체하시오.

# %%
# 그리고, 해당 컬럼의 결측치 대치 전후의 표준편차 차이의 절댓값을 소수점 이하 셋째짜리까지 구하시오.

# %%
# 결측치 대체

# %% [markdown]
# ## 1-3

# %% [markdown]
# Q. 주어진 데이터의 DIS 평균으로부터 1.5 * 표준편차를 벗어나는 영역을 이상치라고 판단하고 DIS 컬럼의 이상치들의 합을 구하시오.

# %% [markdown]
# - 답) 404.4101

# %%
# DIS 평균으로부터 1.5 * 표준편차를 벗어나는 영역을 이상치라고 판단하고

# %%
# DIS 컬럼의 이상치들의 합을 구하시오.

# %% [markdown]
# # Q2

# %% [markdown]
# ## 2-1

# %% [markdown]
# Q. 다음은 캘리포니아 집 값 데이터이다. 결측치가 하나라도 존재하는 행의 경우 해당 행을 삭제하시오. 그후 남은 데이터의 상위 70%에 해당하는 데이터만 남겨둔 후 median_income 컬럼의 1분위수를 반올림하여 소수점 이하 둘째자리까지 구하시오.
#
# - data : https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e3_p1_1.csv

# %% [markdown]
# - 답) 2.51

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np

# %%
# 데이터 불러오기
data = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e3_p1_1.csv')

# %%
# 결측치가 하나라도 존재하는 행의 경우 해당 행을 삭제하시오.

# %%
# 그후 남은 데이터의 상위 70%에 해당하는 데이터만 남겨둔 후

# %%
# median_income 컬럼의 1분위수를 반올림하여 소수점 이하 둘째자리까지 구하시오.

# %% [markdown]
# ## 2-2

# %% [markdown]
# Q. 1990년도는 해당 년도 평균 이하 GDP를 가지지만, 2010년도에는 해당 년도 평균 이상 GDP를 가지는 국가의 숫자를 구하시오.
#
# - data : https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e3_p1_2.csv

# %% [markdown]
# - 답) 5

# %%
# 데이터 불러오기
data = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e3_p1_2.csv')

# %%
# 1990년도는 해당 년도 평균 이하 GDP를 가지지만,

# %%
# 2010년도에는 해당 년도 평균 이상 GDP를 가지는

# %%
# 국가의 숫자를 구하시오.
# Out:
# 5

# %% [markdown]
# ## 2-3

# %% [markdown]
# Q. 다음은 타이타닉 탑승자 생존 데이터이다. 데이터에서 결측치가 가장 많은 컬럼을 출력하시오.
#
# - data : https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e3_p1_3.csv

# %% [markdown]
# - 답) Fare

# %%
# 데이터 불러오기
data = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e3_p1_3.csv')

# %%
# 결측치가 가장 많은 컬럼을 출력하시오.

# %% [markdown]
# # Q3

# %% [markdown]
# ## 3-1

# %% [markdown]
# Q. 다음은 월마트 판매량 데이터이다. Temperature 컬럼에서 숫자가 아닌 문자들을 제거한 후 숫자 타입으로 바꾸고 3분위수에서 1분위수의 차이를 소수점 이하 둘째자리까지 구하시오.
#
# - data : https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e4_p1_1.csv

# %% [markdown]
# - 답) 27.48

# %%
# 데이터 불러오기
data = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e4_p1_1.csv')

# %%
# Temperature 컬럼에서 숫자가 아닌 문자들을 제거한 후 숫자 타입으로 바꾸고

# %%
# 3분위수에서 1분위수의 차이를 소수점 이하 둘째자리까지 구하시오.

# %% [markdown]
# ## 3-2

# %% [markdown]
# Q. 다음은 유튜브 영상 통계량 데이터이다. Likes를 Comments로 나눈 비율이 20 이상이면서 Keyword 값이 minecraft인 영상들의 Views 값의 평균을 정수로 구하시오.
#
# - data : https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e4_p1_2.csv

# %% [markdown]
# - 답) 1789084

# %%
# 데이터 불러오기
data = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e4_p1_2.csv')

# %%
# Likes를 Comments로 나눈 비율이 20 이상이면서

# %%
# Keyword 값이 minecraft인 영상들의

# %%
# Views 값의 평균을 정수로 구하시오.

# %% [markdown]
# ## 3-3

# %% [markdown]
# Q. 다음은 구독 서비스의 영상 데이터이다. date_added가 2018년 1월이면서 country가 United Kingdom 단독 제작인 데이터의 개수를 구하시오.
#
# - data : https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e4_p1_3.csv

# %% [markdown]
# - 답) 6

# %%
# 데이터 불러오기
data = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e4_p1_3.csv')

# %%
# date_added가 2018년 1월이면서

# %%
# country가 United Kingdom 단독 제작인

# %%
# 데이터의 개수를 구하시오.
