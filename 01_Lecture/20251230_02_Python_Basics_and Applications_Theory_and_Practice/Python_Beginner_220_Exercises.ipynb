# %% [markdown]
# # 파이썬 초보자 연습문제 (업데이트 버전)

# %% [markdown]
# # 참고
# ```python
#
# # 함수 파라미터 옆에 str, list 등의 타입은 신경쓰지 않아도 됩니다.
# def join_with_dash(words: list[str]) -> str:
#     # TODO
#     pass
#
# #  assert 는 코드에 문제가 있으면 에러룰 뱉습니다
# # 에러
# x = 123
# assert x ==122
#
# # 동작
# x = 123
# assert x ==123
# ```

# %%
# 에러
x = 123
assert x ==122
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 # 에러
#       2 x = 123
# ----> 3 assert x ==122
#
# AssertionError:

# %%
x = 123
assert x ==123

# %% [markdown]
# ## Part 1. 데이터 타입 / 타입 변환 / 타입 예제 (30문제)
# (앞의 절반은 쉬움, 뒤의 절반은 응용)

# %% [markdown]
# ### [P1-05] (쉬움) 문자열로 변환
#
# 정수 `k`를 문자열로 바꿔 `text`에 저장하세요.

# %%
k = 900

# TODO
text = None


assert text == "900" and isinstance(text, str)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 7
#       3 # TODO
#       4 text = None
# ----> 7 assert text == "900" and isinstance(text, str)
#
# AssertionError:

# %% [markdown]
# ### [P1-06] (쉬움) 불리언 변환 1
#
# `0`을 `bool`로 변환한 결과를 `flag`에 저장하세요.

# %%
# TODO
flag = None

assert flag is False

# %% [markdown]
# ### [P1-07] (쉬움) 불리언 변환 2
#
# 빈 문자열 `''`을 `bool`로 변환한 결과를 `flag`에 저장하세요.

# %%
# TODO
flag = None


assert flag is False

# %% [markdown]
# ### [P1-08] (쉬움) 리스트 만들기
#
# 문자열 `s`를 문자 단위로 쪼갠 리스트를 `chars`에 저장하세요.

# %%
s = "python"

# TODO
chars = None


assert chars == ["p","y","t","h","o","n"]

# %% [markdown]
# ### [P1-09] (쉬움) 튜플 만들기
#
# 리스트 `nums`를 튜플로 변환해 `t`에 저장하세요.

# %%
nums = [1, 2, 3]

# TODO
t = None


assert t == (1,2,3) and isinstance(t, tuple)

# %% [markdown]
# ### [P1-10] (쉬움) 집합 만들기
#
# 리스트 `items`에서 중복을 제거해 집합 `st`로 만드세요.

# %%
items = [1, 1, 2, 3, 3]

# TODO
st = None


assert st == {1,2,3}

# %% [markdown]
# ### [P1-11] (쉬움) 딕셔너리 접근
#
# 딕셔너리 `person`에서 나이 값을 `age`에 저장하세요.

# %%
person = {"name": "min", "age": 20}

# TODO
age = None


assert age == 20

# %% [markdown]
# ### [P1-12] (쉬움) 슬라이싱 1
#
# 리스트 `nums`의 앞 3개를 `first3`에 저장하세요.

# %%
nums = [10, 20, 30, 40, 50]

# TODO
first3 = None

assert first3 == [10,20,30]

# %% [markdown]
# ### [P1-13] (쉬움) 슬라이싱 2
#
# 문자열 `s`에서 뒤에서 2글자를 `tail`에 저장하세요.

# %%
s = "abcdef"

# TODO
tail = None

assert tail == "ef"

# %% [markdown]
# ### [P1-14] (쉬움) 형변환 조합
#
# 문자열 `s`를 정수로 바꾸고 1을 더해 다시 문자열로 만든 값을 `out`에 저장하세요.

# %%
s = "99"

# TODO
out = None


assert out == "100"

# %% [markdown]
# ### [P1-15] (쉬움) 리스트 -> 문자열
#
# 문자 리스트 `letters`를 이어붙여 문자열 `word`를 만드세요.

# %%
letters = ["c", "o", "d", "e"]

# TODO
word = None


assert word == "code"

# %% [markdown]
# ### [P1-16] (응용) safe_int
#
# 문자열 `s`가 정수로 변환 가능하면 정수로, 아니면 `None`을 반환하는 함수 `safe_int(s)`를 작성하세요.
# - 예: `safe_int('12') -> 12`, `safe_int('12.3') -> None`

# %%
def safe_int(s: str):
    # TODO
    pass


assert safe_int("12") == 12
assert safe_int("-7") == -7
assert safe_int("12.3") is None
assert safe_int("abc") is None

# %% [markdown]
# ### [P1-17] (응용) to_float_str
#
# 정수 또는 실수 `x`를 **소수점 둘째자리까지** 문자열로 반환하는 함수 `to_float_str(x)`를 작성하세요.
# - 예: `to_float_str(3) -> '3.00'`, `to_float_str(2.5) -> '2.50'`

# %%
def to_float_str(x):
    # TODO
    pass


assert to_float_str(3) == "3.00"
assert to_float_str(2.5) == "2.50"
assert to_float_str(2.567) == "2.57"

# %% [markdown]
# ### [P1-18] (응용) is_digit_string
#
# `s`가 숫자 문자만으로 이루어졌는지 확인하는 함수 `is_digit_string(s)`를 작성하세요.
# - 빈 문자열은 False로 처리하세요.

# %%
def is_digit_string(s: str) -> bool:
    # TODO
    pass


assert is_digit_string("123") is True
assert is_digit_string("001") is True
assert is_digit_string("") is False
assert is_digit_string("12a") is False

# %% [markdown]
# ### [P1-19] (응용) parse_bool
#
# 문자열 `s`가 `'true'` 또는 `'false'`(대소문자 무시)면 해당 bool 값을 반환하고, 그 외에는 `None`을 반환하는 `parse_bool(s)`를 작성하세요.

# %%
def parse_bool(s: str):
    # TODO
    pass


assert parse_bool("true") is True
assert parse_bool("FALSE") is False
assert parse_bool("TrUe") is True
assert parse_bool("yes") is None

# %% [markdown]
# ### [P1-20] (응용) swap_types
#
# `a`는 정수, `b`는 문자열 숫자입니다. `a`를 문자열로, `b`를 정수로 바꿔서 `(a2, b2)`를 반환하는 함수 `swap_types(a, b)`를 작성하세요.

# %%
def swap_types(a: int, b: str):
    # TODO
    pass


assert swap_types(7, "8") == ("7", 8)

# %% [markdown]
# ### [P1-21] (응용) list_of_ints
#
# 문자열 리스트 `arr`(예: ['1','2','3'])를 정수 리스트로 변환하는 함수 `list_of_ints(arr)`를 작성하세요.

# %%
def list_of_ints(arr: list[str]) -> list[int]:
    # TODO
    pass


assert list_of_ints(["1","2","3"]) == [1,2,3]
assert list_of_ints([]) == []

# %% [markdown]
# ### [P1-22] (응용) join_with_dash
#
# 문자열 리스트 `words`를 `-`로 연결한 문자열을 반환하는 `join_with_dash(words)`를 작성하세요.

# %%
def join_with_dash(words: list[str]) -> str:
    # TODO
    pass


assert join_with_dash(["a","b","c"]) == "a-b-c"
assert join_with_dash(["solo"]) == "solo"
assert join_with_dash([]) == ""

# %% [markdown]
# ### [P1-23] (응용) split_csv
#
# 쉼표로 구분된 문자열 `s`를 요소 리스트로 반환하는 `split_csv(s)`를 작성하세요.
# - 공백은 유지하지 말고, 각 요소의 양끝 공백은 제거하세요.

# %%
def split_csv(s: str) -> list[str]:
    # TODO
    pass


assert split_csv("a,b,c") == ["a","b","c"]
assert split_csv(" a,  b ,c ") == ["a","b","c"]
assert split_csv("") == [""]

# %% [markdown]
# ### [P1-24] (응용) as_tuple2
#
# 리스트 `arr`의 길이가 2일 때 `(arr[0], arr[1])` 튜플로 바꾸는 함수 `as_tuple2(arr)`를 작성하세요.

# %%
def as_tuple2(arr: list):
    # TODO
    pass


assert as_tuple2([10, 20]) == (10, 20)

# %% [markdown]
# ### [P1-25] (응용) dict_from_pairs
#
# 2원소 리스트 쌍들의 리스트 `pairs`를 딕셔너리로 변환하는 `dict_from_pairs(pairs)`를 작성하세요.
# - 예: `[['a',1],['b',2]] -> {'a':1,'b':2}`

# %%
def dict_from_pairs(pairs: list[list]):
    # TODO
    pass


assert dict_from_pairs([["a",1],["b",2]]) == {"a":1,"b":2}
assert dict_from_pairs([]) == {}

# %% [markdown]
# ### [P1-26] (응용) type_summary
#
# 리스트 `items`에 들어있는 값들의 타입 이름을 같은 순서로 리스트로 반환하는 `type_summary(items)`를 작성하세요.

# %%
def type_summary(items: list):
    # TODO
    pass


assert type_summary([1, 2.0, "x", True, [1]]) == ["int","float","str","bool","list"]

# %% [markdown]
# ### [P1-27] (응용) safe_get
#
# 딕셔너리 `d`에서 키 `k`가 있으면 값, 없으면 `default`를 반환하는 `safe_get(d, k, default)`를 작성하세요.

# %%
def safe_get(d: dict, k, default=None):
    # TODO
    pass


assert safe_get({"a":1}, "a", 0) == 1
assert safe_get({"a":1}, "b", 0) == 0

# %% [markdown]
# ### [P1-28] (응용) str_repeat
#
# 문자열 `s`를 `n`번 반복한 문자열을 반환하는 `str_repeat(s, n)`을 작성하세요.

# %%
def str_repeat(s: str, n: int) -> str:
    # TODO
    pass


assert str_repeat("ha", 3) == "hahaha"
assert str_repeat("x", 0) == ""

# %% [markdown]
# ### [P1-29] (응용) to_int_then_float
#
# 문자열 `s`를 정수로 바꾼 뒤 0.5를 더해서 실수로 반환하는 `to_int_then_float(s)`를 작성하세요.

# %%
def to_int_then_float(s: str) -> float:
    # TODO
    pass


assert to_int_then_float("3") == 3.5

# %% [markdown]
# ### [P1-30] (응용) bool_toggle
#
# 불리언 `b`를 반대로 뒤집어서 반환하는 함수 `bool_toggle(b)`를 작성하세요. (`not` 사용)

# %%
def bool_toggle(b: bool) -> bool:
    # TODO
    pass


assert bool_toggle(True) is False
assert bool_toggle(False) is True

# %% [markdown]
# ## Part 2. 비교 연산자 (30문제)
# - 리스트/빈 컨테이너 직접 비교 문제는 포함하지 않습니다.
# - `not` 반전 문제를 여러 개 포함합니다.

# %% [markdown]
# ### [P2-01] (쉬움) 숫자 비교 1
#
# 표현식 `a < b`의 결과를 `result`에 저장하세요.

# %%
a = 3
b = 5
# TODO
result = None


assert result is True

# %% [markdown]
# ### [P2-02] (쉬움) 숫자 비교 2
#
# `a >= b` 결과를 구하세요.

# %%
a = 10
b = 10
# TODO
result = None


assert result is True

# %% [markdown]
# ### [P2-03] (쉬움) 문자열 비교 1
#
# `'apple' < 'banana'`의 결과를 구하세요.

# %%
# TODO
result = None


assert result is True

# %% [markdown]
# ### [P2-04] (쉬움) 길이 비교
#
# 문자열 `s`의 길이가 5보다 큰지 비교해 `result`에 저장하세요.

# %%
s = 'hello!'
# TODO
result = None

assert result is True

# %% [markdown]
# ### [P2-05] (쉬움) 멤버십 1
#
# 문자열 `s`에 `'py'`가 포함되어 있는지 `result`에 저장하세요.

# %%
s='python'
# TODO
result=None


assert result is True

# %% [markdown]
# ### [P2-06] (쉬움) 멤버십 2
#
# 리스트 `nums`에 7이 **없는지** (`not in`) `result`에 저장하세요.

# %%
nums=[1,2,3]
# TODO
result=None


assert result is True

# %% [markdown]
# ### [P2-07] (쉬움) 논리 AND
#
# `a > 0` 그리고 `b > 0` 둘 다 참인지 `result`를 구하세요.

# %%
a=1
b=2
# TODO
result=None

assert result is True

# %% [markdown]
# ### [P2-08] (쉬움) 논리 OR
#
# `a < 0` 또는 `b < 0` 중 하나라도 참인지 `result`를 구하세요.

# %%
a=1
b=-1
# TODO
result=None


assert result is True

# %% [markdown]
# ### [P2-09] (쉬움) not 1
#
# `x`가 10이 **아닌지** `result`를 구하세요. (`not` 사용)

# %%
x=11
# TODO
result=None

assert result is True

# %% [markdown]
# ### [P2-10] (쉬움) not 2
#
# `flag`의 반대값을 `result`로 구하세요.

# %%
flag=False
# TODO
result=None


assert result is True

# %% [markdown]
# ### [P2-11] (쉬움) 체인 비교
#
# `0 <= x < 10` 형태로 `x`가 한 자리 수인지 `result`를 구하세요.

# %%
x=7
# TODO
result=None
result

assert result is True

# %% [markdown]
# ### [P2-12] (쉬움) 대소문자 무시 비교
#
# 문자열 `a`, `b`를 소문자로 바꿔서 같은지 비교하세요.

# %%
a='Py'
b='py'
# TODO
result=None


assert result is True

# %% [markdown]
# ### [P2-13] (쉬움) is vs ==
#
# `a`와 `b`가 같은 값인지 `==`로 비교한 결과를 `eq`에 저장하세요.

# %%
a=1000
b=1000
# TODO
eq=None


assert eq is True

# %% [markdown]
# ### [P2-14] (쉬움) 부등호 반전
#
# `not (a < b)`의 값을 `result`로 구하세요.

# %%
a=5
b=3
# TODO
result=None


assert result is True

# %% [markdown]
# ### [P2-15] (쉬움) 복합 not
#
# `not (x >= 3 and x <= 7)`의 결과를 구하세요.

# %%
x=2
# TODO
result=None


assert result is True

# %% [markdown]
# ### [P2-16] (응용) is_even
#
# 정수 `n`이 짝수면 True, 아니면 False를 반환하는 `is_even(n)`을 작성하세요.

# %%
def is_even(n: int) -> bool:
    # TODO
    pass


assert is_even(2) is True
assert is_even(7) is False

# %% [markdown]
# ### [P2-17] (응용) is_odd_using_not
#
# 정수 `n`이 홀수인지 판별하는 `is_odd_using_not(n)`을 작성하세요.
# - `not`을 **반드시 한 번 이상** 사용하세요.

# %%
def is_odd_using_not(n: int) -> bool:
    # TODO
    pass


assert is_odd_using_not(3) is True
assert is_odd_using_not(10) is False

# %% [markdown]
# ### [P2-18] (응용) is_between
#
# `low <= x <= high`면 True를 반환하는 `is_between(x, low, high)`를 작성하세요.

# %%
def is_between(x, low, high) -> bool:
    # TODO
    pass


assert is_between(5, 1, 10) is True
assert is_between(0, 1, 10) is False

# %% [markdown]
# ### [P2-19] (응용) is_not_between
#
# `x`가 구간 `[low, high]` 밖이면 True를 반환하는 `is_not_between(x, low, high)`를 작성하세요.
# - `not` 사용

# %%
def is_not_between(x, low, high) -> bool:
    # TODO
    pass


assert is_not_between(0, 1, 10) is True
assert is_not_between(5, 1, 10) is False

# %% [markdown]
# ### [P2-20] (응용) starts_with_not
#
# 문자열 `s`가 접두사 `prefix`로 **시작하지 않으면** True를 반환하는 `starts_with_not(s, prefix)`를 작성하세요.

# %%
def starts_with_not(s: str, prefix: str) -> bool:
    # TODO
    pass


assert starts_with_not("python", "py") is False
assert starts_with_not("python", "ja") is True

# %% [markdown]
# ### [P2-21] (응용) ends_with
#
# 문자열 `s`가 `suffix`로 끝나면 True, 아니면 False.

# %%
def ends_with(s: str, suffix: str) -> bool:
    # TODO
    pass


assert ends_with("hello", "lo") is True
assert ends_with("hello", "la") is False

# %% [markdown]
# ### [P2-22] (응용) contains_all
#
# 문자열 `s`에 `a`와 `b`가 모두 포함되어 있으면 True를 반환하는 `contains_all(s, a, b)`를 작성하세요.

# %%
def contains_all(s: str, a: str, b: str) -> bool:
    # TODO
    pass


assert contains_all("banana", "a", "n") is True
assert contains_all("banana", "x", "a") is False

# %% [markdown]
# ### [P2-23] (응용) is_single_char
#
# `s`가 길이 1인 문자열인지 판별하는 `is_single_char(s)`를 작성하세요.

# %%
def is_single_char(s: str) -> bool:
    # TODO
    pass


assert is_single_char("a") is True
assert is_single_char("") is False
assert is_single_char("ab") is False

# %% [markdown]
# ### [P2-24] (응용) pass_fail
#
# 점수 `score`가 60 이상이면 'PASS', 아니면 'FAIL'을 반환하는 `pass_fail(score)`를 작성하세요.

# %%
def pass_fail(score: int) -> str:
    # TODO
    pass


assert pass_fail(60) == "PASS"
assert pass_fail(59) == "FAIL"

# %% [markdown]
# ### [P2-25] (응용) is_uppercase_letter
#
# 문자 `ch`가 대문자 알파벳('A'~'Z')이면 True를 반환하세요.

# %%
def is_uppercase_letter(ch: str) -> bool:
    # TODO
    pass


assert is_uppercase_letter("A") is True
assert is_uppercase_letter("Z") is True
assert is_uppercase_letter("a") is False

# %% [markdown]
# ### [P2-26] (응용) is_lowercase_letter
#
# 문자 `ch`가 소문자 알파벳('a'~'z')이면 True를 반환하세요.

# %%
def is_lowercase_letter(ch: str) -> bool:
    # TODO
    pass


assert is_lowercase_letter("a") is True
assert is_lowercase_letter("z") is True
assert is_lowercase_letter("A") is False

# %% [markdown]
# ### [P2-27] (응용) xor_bool
#
# 불리언 `a`, `b`가 서로 다를 때만 True인 XOR를 구현하는 `xor_bool(a, b)`를 작성하세요.
# - `not`을 사용해도 좋습니다.

# %%
def xor_bool(a: bool, b: bool) -> bool:
    # TODO
    pass


assert xor_bool(True, False) is True
assert xor_bool(False, True) is True
assert xor_bool(True, True) is False
assert xor_bool(False, False) is False

# %% [markdown]
# ### [P2-28] (응용) not_contains
#
# 문자열 `s`에 부분문자열 `sub`가 **포함되어 있지 않으면** True를 반환하는 `not_contains(s, sub)`를 작성하세요.

# %%
def not_contains(s: str, sub: str) -> bool:
    # TODO
    pass


assert not_contains("codeit", "z") is True
assert not_contains("codeit", "it") is False

# %% [markdown]
# ### [P2-29] (응용) is_valid_id
#
# 아이디 `s`가 길이 4 이상 12 이하이고 공백이 없으면 True를 반환하는 `is_valid_id(s)`를 작성하세요.
# - 공백 여부는 `' ' in s`로 검사 가능

# %%
def is_valid_id(s: str) -> bool:
    # TODO
    pass


assert is_valid_id("user1") is True
assert is_valid_id("ab") is False
assert is_valid_id("too long id here") is False

# %% [markdown]
# ### [P2-30] (응용) not_all_positive
#
# 리스트 `nums`에서 **모두 양수**가 아니라면 True를 반환하는 `not_all_positive(nums)`를 작성하세요.
# - `nums`는 비어있지 않습니다.
# - `not` 사용

# %%
def not_all_positive(nums: list[int]) -> bool:
    # TODO
    pass


assert not_all_positive([1,2,3]) is False
assert not_all_positive([1,-2,3]) is True

# %% [markdown]
# ## Part 3. for문 (40문제)
# - 리스트 컴프리헨션 문제 포함
# - 별찍기 문제 포함
# - `enumerate`, `zip` 사용 금지

# %% [markdown]
# ### [P3-01] (쉬움) 1부터 n까지 합
#
# `n`까지의 합을 for문으로 계산해 반환하는 `sum_to_n(n)`을 작성하세요.

# %%
def sum_to_n(n: int) -> int:
    # TODO
    pass


assert sum_to_n(1) == 1
assert sum_to_n(5) == 15

# %% [markdown]
# ### [P3-02] (쉬움) 리스트 합
#
# 정수 리스트 `nums`의 합을 for문으로 구해 반환하는 `sum_list(nums)`를 작성하세요.

# %%
def sum_list(nums: list[int]) -> int:
    # TODO
    pass


assert sum_list([1,2,3]) == 6
assert sum_list([]) == 0

# %% [markdown]
# ### [P3-03] (쉬움) 짝수 개수
#
# 리스트 `nums`에서 짝수의 개수를 반환하는 `count_even(nums)`를 작성하세요.

# %%
def count_even(nums: list[int]) -> int:
    # TODO
    pass


assert count_even([1,2,4,7]) == 2

# %% [markdown]
# ### [P3-04] (쉬움) 특정 문자 개수
#
# 문자열 `s`에서 문자 `ch`가 몇 번 나오는지 반환하는 `count_char(s, ch)`를 작성하세요.

# %%
def count_char(s: str, ch: str) -> int:
    # TODO
    pass


assert count_char("banana", "a") == 3

# %% [markdown]
# ### [P3-05] (쉬움) 대문자 만들기
#
# 문자열 `s`의 각 문자를 대문자로 바꾼 새 문자열을 반환하는 `to_upper_manual(s)`를 작성하세요.
# - `s.upper()` 사용 금지 (for로 직접 만들기)

# %%
def to_upper_manual(s: str) -> str:
    # TODO
    pass


assert to_upper_manual("Abc") == "ABC"

# %% [markdown]
# ### [P3-06] (쉬움) 리스트 필터 1
#
# 리스트 `nums`에서 0보다 큰 값만 모아 새 리스트를 반환하세요.

# %%
def positives(nums: list[int]) -> list[int]:
    # TODO
    pass


assert positives([-1,0,2,3]) == [2,3]

# %% [markdown]
# ### [P3-07] (쉬움) 리스트 변환 1
#
# 리스트 `nums`의 각 원소를 제곱한 리스트를 반환하세요.

# %%
def squares(nums: list[int]) -> list[int]:
    # TODO
    pass


assert squares([1,2,3]) == [1,4,9]

# %% [markdown]
# ### [P3-08] (쉬움) 문자열 뒤집기
#
# 문자열 `s`를 for문으로 뒤집은 결과를 반환하세요.
# - 슬라이싱 `s[::-1]` 사용 금지

# %%
def reverse_str(s: str) -> str:
    # TODO
    pass


assert reverse_str("abc") == "cba"

# %% [markdown]
# ### [P3-09] (쉬움) 최대값 찾기
#
# 비어있지 않은 리스트 `nums`에서 최대값을 for문으로 찾아 반환하세요.
# - `max()` 사용 금지

# %%
def max_manual(nums: list[int]) -> int:
    # TODO
    pass


assert max_manual([3,1,9,2]) == 9

# %% [markdown]
# ### [P3-10] (쉬움) 문자열에서 공백 제거
#
# 문자열 `s`에서 공백 문자 `' '`를 제거한 새 문자열을 반환하세요.

# %%
def remove_spaces(s: str) -> str:
    # TODO
    pass


assert remove_spaces("a b  c") == "abc"

# %% [markdown]
# ### [P3-11] (쉬움) 리스트 컴프리헨션 1
#
# 리스트 `nums`에서 홀수만 뽑아 새 리스트로 만드세요. (리스트 컴프리헨션 사용)

# %%
def odds_lc(nums: list[int]) -> list[int]:
    # TODO
    pass


assert odds_lc([1,2,3,4,5]) == [1,3,5]

# %% [markdown]
# ### [P3-12] (쉬움) 리스트 컴프리헨션 2
#
# 문자열 리스트 `words`에서 길이가 3 이상인 단어만 남긴 리스트를 반환하세요. (LC)

# %%
def long_words(words: list[str]) -> list[str]:
    # TODO
    pass


assert long_words(["a","to","you","python"]) == ["you","python"]

# %% [markdown]
# ### [P3-13] (쉬움) 리스트 컴프리헨션 3
#
# 0부터 n-1까지의 제곱 리스트를 반환하세요. (LC)

# %%
def squares_range(n: int) -> list[int]:
    # TODO
    pass


assert squares_range(5) == [0,1,4,9,16]

# %% [markdown]
# ### [P3-14] (쉬움) 중첩 for 1
#
# 2차원 리스트 `grid`의 모든 원소 합을 반환하세요.

# %%
def sum_grid(grid: list[list[int]]) -> int:
    # TODO
    pass


assert sum_grid([[1,2],[3,4]]) == 10

# %% [markdown]
# ### [P3-15] (쉬움) 구구단 한 줄
#
# `n`단 결과를 문자열 리스트로 반환하세요.
# - 예: n=2 -> ['2 x 1 = 2', ..., '2 x 9 = 18']

# %%
def gugudan_line(n: int) -> list[str]:
    # TODO
    pass


assert gugudan_line(2)[0] == "2 x 1 = 2"
assert gugudan_line(2)[-1] == "2 x 9 = 18"

# %% [markdown]
# ### [P3-16] (쉬움) 별찍기 1
#
# 높이 `n`인 왼쪽 정렬 삼각형을 문자열로 반환하세요.
# - 각 줄 끝에 `\n` 포함, 마지막 줄도 `\n` 포함
# - n=3이면:
# ```
# *
# **
# ***
# ```

# %%
def stars_left(n: int) -> str:
    # TODO
    pass


assert stars_left(1) == '''*
'''
assert stars_left(3) == '''*
**
***
'''

# %% [markdown]
# ### [P3-17] (쉬움) 별찍기 2
#
# 높이 `n`인 오른쪽 정렬 삼각형을 문자열로 반환하세요.
# - n=3이면:
# ```
#   *
#  **
# ***
# ```

# %%
def stars_right(n: int) -> str:
    # TODO
    pass


assert stars_right(3) == '''  *
 **
***
'''

# %% [markdown]
# ### [P3-18] (쉬움) 별찍기 3
#
# 높이 `n`인 피라미드(가운데 정렬)를 문자열로 반환하세요.
# - n=3이면:
# ```
#   *
#  ***
# *****
# ```

# %%
def stars_pyramid(n: int) -> str:
    # TODO
    pass


assert stars_pyramid(3) == '''  *
 ***
*****
'''

# %% [markdown]
# ### [P3-19] (쉬움) 문자열 누적
#
# 문자열 리스트 `parts`를 순서대로 이어붙인 문자열을 반환하세요.
# - `''.join()` 사용 금지

# %%
def concat_manual(parts: list[str]) -> str:
    # TODO
    pass


assert concat_manual(["py","thon"]) == "python"
assert concat_manual([]) == ""

# %% [markdown]
# ### [P3-20] (쉬움) 인덱스 사용
#
# 리스트 `nums`의 원소에 인덱스를 더한 새 리스트를 반환하세요.
# - 예: [10,10,10] -> [10,11,12]
# - `enumerate` 금지: `range(len(nums))`를 사용하세요.

# %%
def add_index(nums: list[int]) -> list[int]:
    # TODO
    pass


assert add_index([10,10,10]) == [10,11,12]

# %% [markdown]
# ### [P3-21] (응용) 리스트 컴프리헨션 4
#
# 문자열 `s`에서 모음(a,e,i,o,u)을 제외한 문자만 모아 새 문자열을 반환하세요. (for 또는 LC)
# - 공백은 그대로 유지

# %%
def remove_vowels_str(s: str) -> str:
    # TODO
    pass


assert remove_vowels_str("codeit") == "cdt"
assert remove_vowels_str("python programming") == "pythn prgrmmng"

# %% [markdown]
# ### [P3-22] (응용) 중복 제거 유지
#
# 리스트 `items`에서 **처음 등장한 순서**를 유지하며 중복을 제거한 리스트를 반환하세요.

# %%
def unique_keep_order(items: list) -> list:
    # TODO
    pass


assert unique_keep_order([1,1,2,1,3,2]) == [1,2,3]

# %% [markdown]
# ### [P3-23] (응용) 단어 길이 맵
#
# 문자열 리스트 `words`를 받아 `{단어:길이}` 딕셔너리를 반환하세요.

# %%
def word_lengths(words: list[str]) -> dict[str,int]:
    # TODO
    pass


assert word_lengths(["a","to","you"]) == {"a":1,"to":2,"you":3}

# %% [markdown]
# ### [P3-24] (응용) 문자 빈도
#
# 문자열 `s`의 각 문자 빈도를 딕셔너리로 반환하세요.
# - 예: 'aba' -> {'a':2,'b':1}

# %%
def char_freq(s: str) -> dict[str,int]:
    # TODO
    pass


assert char_freq("aba") == {"a":2,"b":1}

# %% [markdown]
# ### [P3-25] (응용) 리스트 컴프리헨션 5
#
# 리스트 `nums`에서 3의 배수는 'X', 아니면 숫자를 그대로 둔 새 리스트를 반환하세요. (LC)

# %%
def mask_multiples_of_three(nums: list[int]) -> list:
    # TODO
    pass


assert mask_multiples_of_three([1,3,4,6,7,9]) == [1,"X",4,"X",7,"X"]

# %% [markdown]
# ### [P3-26] (응용) 중첩 별찍기 4
#
# 가로 `w`, 세로 `h`인 직사각형 별을 문자열로 반환하세요.
# - 각 줄은 `'*' * w`

# %%
def stars_rect(w: int, h: int) -> str:
    # TODO
    pass


assert stars_rect(3,2) == '''***
***
'''

# %% [markdown]
# ### [P3-27] (응용) 계단 별찍기
#
# 높이 `n`인 계단 모양을 문자열로 반환하세요.
# - n=4:
# ```
# #
# ##
# ###
# ####
# ```
# - 문자는 `#` 사용

# %%
def stairs_hash(n: int) -> str:
    # TODO
    pass


assert stairs_hash(2) == '''#
##
'''

# %% [markdown]
# ### [P3-28] (응용) 구분자로 감싸기
#
# 문자열 리스트 `words`를 받아 각 단어를 괄호로 감싼 새 리스트를 반환하세요.
# - 예: ['a','b'] -> ['(a)','(b)']

# %%
def wrap_parentheses(words: list[str]) -> list[str]:
    # TODO
    pass


assert wrap_parentheses(["a","bb"]) == ["(a)","(bb)"]

# %% [markdown]
# ### [P3-29] (응용) 문자열 교대로
#
# 문자열 `s`의 짝수 인덱스 문자만 모아 반환하세요.
# - `enumerate` 금지

# %%
def even_index_chars(s: str) -> str:
    # TODO
    pass


assert even_index_chars("abcdef") == "ace"

# %% [markdown]
# ### [P3-30] (응용) 문자열 압축(기초)
#
# 연속된 같은 문자를 `문자+개수` 형태로 압축하는 함수 `rle_basic(s)`를 작성하세요.
# - 예: 'aaabb' -> 'a3b2'
# - 빈 문자열이면 ''

# %%
def rle_basic(s: str) -> str:
    # TODO
    pass


assert rle_basic("") == ""
assert rle_basic("aaabb") == "a3b2"
assert rle_basic("abcd") == "a1b1c1d1"

# %% [markdown]
# ### [P3-31] (응용) 리스트 회전
#
# 리스트 `arr`를 왼쪽으로 1칸 회전한 새 리스트를 반환하세요.
# - 예: [1,2,3] -> [2,3,1]
# - 빈 리스트면 그대로 반환

# %%
def rotate_left_once(arr: list) -> list:
    # TODO
    pass


assert rotate_left_once([1,2,3]) == [2,3,1]
assert rotate_left_once([]) == []

# %% [markdown]
# ### [P3-32] (응용) 문장 단어 수
#
# 문자열 `s`에서 공백으로 구분된 단어 수를 반환하세요.
# - 연속 공백은 무시 (strip 후 split 사용 가능)

# %%
def count_words(s: str) -> int:
    # TODO
    pass


assert count_words("python is fun") == 3
assert count_words("  a   b ") == 2

# %% [markdown]
# ### [P3-33] (응용) 리스트 컴프리헨션 6
#
# 0~n 사이(포함)에서 짝수만 모은 리스트를 반환하세요. (LC)

# %%
def evens_upto(n: int) -> list[int]:
    # TODO
    pass


assert evens_upto(6) == [0,2,4,6]

# %% [markdown]
# ### [P3-34] (응용) 숫자 문자열만 남기기
#
# 문자열 `s`에서 숫자 문자만 추출해 새 문자열을 반환하세요.

# %%
def keep_digits(s: str) -> str:
    # TODO
    pass


assert keep_digits("a1b2c3") == "123"

# %% [markdown]
# ### [P3-35] (응용) 대소문자 토글
#
# 문자열 `s`의 각 문자의 대소문자를 반대로 바꾼 문자열을 반환하세요.
# - `swapcase()` 사용 금지

# %%
def toggle_case(s: str) -> str:
    # TODO
    pass


assert toggle_case("aBc") == "AbC"

# %% [markdown]
# ### [P3-36] (응용) 누적 문자열 리스트
#
# 문자열 리스트 `parts`에 대해, 누적해서 붙인 결과 리스트를 반환하세요.
# - 예: ['a','b','c'] -> ['a','ab','abc']

# %%
def cumulative_concat(parts: list[str]) -> list[str]:
    # TODO
    pass


assert cumulative_concat(["a","b","c"]) == ["a","ab","abc"]

# %% [markdown]
# ### [P3-37] (응용) 문자열 그룹
#
# 문자열 `s`를 길이 `k`씩 끊어 리스트로 반환하세요.
# - 마지막이 남으면 그대로 포함
# - 예: ('abcdef',2) -> ['ab','cd','ef']

# %%
def chunk_string(s: str, k: int) -> list[str]:
    # TODO
    pass


assert chunk_string("abcdef",2) == ["ab","cd","ef"]
assert chunk_string("abcde",2) == ["ab","cd","e"]

# %% [markdown]
# ### [P3-38] (응용) 별찍기 5
#
# 높이 `n`인 다이아몬드의 윗부분(피라미드)만 출력하는 문자열을 반환하세요.
# - n=3:
# ```
#   *
#  ***
# *****
# ```

# %%
def diamond_top(n: int) -> str:
    # TODO
    pass


assert diamond_top(1) == '''*
'''

# %% [markdown]
# ### [P3-39] (응용) 리스트 컴프리헨션 7
#
# 문자열 리스트 `words`에서 첫 글자만 뽑아 리스트로 반환하세요. (LC)
# - 빈 문자열은 입력으로 들어오지 않습니다.

# %%
def first_letters(words: list[str]) -> list[str]:
    # TODO
    pass


assert first_letters(["python","code","it"]) == ["p","c","i"]

# %% [markdown]
# ### [P3-40] (응용) 반전 not 응용
#
# 리스트 `nums`에서 **음수가 하나도 없으면** True를 반환하는 `no_negative(nums)`를 작성하세요.
# - `not`을 사용해 구현

# %%
def no_negative(nums: list[int]) -> bool:
    # TODO
    pass


assert no_negative([0,1,2]) is True
assert no_negative([1,-1,2]) is False

# %% [markdown]
# ## Part 4. while문 (40문제)
# - `input()` 사용 금지
# - `break/continue` 문제 포함
# - 누적곱(곱셈 누적) 제거

# %% [markdown]
# ### [P4-01] (쉬움) while로 1부터 n까지 합
#
# for문 대신 while문으로 1~n 합을 구하는 `sum_to_n_while(n)`을 작성하세요.

# %%
def sum_to_n_while(n: int) -> int:
    # TODO
    pass


assert sum_to_n_while(5) == 15

# %% [markdown]
# ### [P4-02] (쉬움) 카운트다운
#
# 정수 `n`부터 1까지의 숫자를 문자열로 한 줄씩 반환하세요.
# - 각 줄 끝에 \n 포함
# - n=3 -> '3\n2\n1\n'

# %%
def countdown_str(n: int) -> str:
    # TODO
    pass


assert countdown_str(3) == '''3
2
1
'''

# %% [markdown]
# ### [P4-03] (쉬움) while로 리스트 합
#
# 리스트 `nums`의 합을 while로 구하는 `sum_list_while(nums)`를 작성하세요.

# %%
def sum_list_while(nums: list[int]) -> int:
    # TODO
    pass


assert sum_list_while([1,2,3]) == 6
assert sum_list_while([]) == 0

# %% [markdown]
# ### [P4-04] (쉬움) 문자열에서 특정 문자 제거
#
# 문자열 `s`에서 문자 `ch`를 제거한 결과를 while로 반환하세요.

# %%
def remove_char_while(s: str, ch: str) -> str:
    # TODO
    pass


assert remove_char_while("banana", "a") == "bnn"

# %% [markdown]
# ### [P4-05] (쉬움) 첫 번째 공백 위치
#
# 문자열 `s`에서 첫 공백의 인덱스를 반환하세요. 없으면 -1.
# - `find()` 사용 금지

# %%
def first_space_index(s: str) -> int:
    # TODO
    pass


assert first_space_index("a b") == 1
assert first_space_index("abc") == -1

# %% [markdown]
# ### [P4-06] (쉬움) 리스트에서 값 찾기
#
# 리스트 `nums`에서 `target`이 처음 등장하는 인덱스를 반환하세요. 없으면 -1.
# - `index()` 사용 금지

# %%
def find_index(nums: list[int], target: int) -> int:
    # TODO
    pass


assert find_index([1,2,3,2], 2) == 1
assert find_index([1,2,3], 9) == -1

# %% [markdown]
# ### [P4-07] (쉬움) 길이 제한 자르기
#
# 문자열 `s`를 길이 `limit`까지만 남겨 반환하세요.
# - `s[:limit]` 사용 금지

# %%
def cut_str(s: str, limit: int) -> str:
    # TODO
    pass


assert cut_str("abcdef", 3) == "abc"
assert cut_str("ab", 3) == "ab"

# %% [markdown]
# ### [P4-08] (쉬움) 누적 덧셈
#
# 정수 `n`에 대해 1부터 더해가며 합이 `n` 이상이 되는 최소 `k`를 반환하세요.
# - 예: n=6 -> 3 (1+2+3=6)

# %%
def min_k_for_sum(n: int) -> int:
    # TODO
    pass


assert min_k_for_sum(1) == 1
assert min_k_for_sum(6) == 3
assert min_k_for_sum(7) == 4

# %% [markdown]
# ### [P4-09] (쉬움) while로 짝수만
#
# 0부터 시작해 `n`보다 작은 짝수들을 리스트로 반환하세요.
# - n=7 -> [0,2,4,6]

# %%
def evens_below(n: int) -> list[int]:
    # TODO
    pass


assert evens_below(7) == [0,2,4,6]

# %% [markdown]
# ### [P4-10] (쉬움) break 1
#
# 리스트 `nums`를 앞에서부터 보며 처음으로 `0`을 만나면 멈추고, 그 전까지의 합을 반환하세요.

# %%
def sum_until_zero(nums: list[int]) -> int:
    # TODO
    pass


assert sum_until_zero([1,2,0,9]) == 3
assert sum_until_zero([0,1,2]) == 0

# %% [markdown]
# ### [P4-11] (쉬움) continue 1
#
# 리스트 `nums`에서 음수는 건너뛰고(continue), 나머지만 합을 반환하세요.

# %%
def sum_skip_negative(nums: list[int]) -> int:
    # TODO
    pass


assert sum_skip_negative([1,-2,3,-4,5]) == 9

# %% [markdown]
# ### [P4-12] (쉬움) 문자열 반복 체크
#
# 문자열 `s`가 같은 문자로만 이루어졌으면 True를 반환하세요.
# - 예: 'aaa' -> True, 'aba' -> False

# %%
def all_same_char(s: str) -> bool:
    # TODO
    pass


assert all_same_char("aaa") is True
assert all_same_char("aba") is False

# %% [markdown]
# ### [P4-13] (쉬움) 반전 not while
#
# 리스트 `nums`에 0이 **없으면** True를 반환하세요.
# - `not`을 사용

# %%
def no_zero(nums: list[int]) -> bool:
    # TODO
    pass


assert no_zero([1,2,3]) is True
assert no_zero([1,0,3]) is False

# %% [markdown]
# ### [P4-14] (쉬움) 별찍기 while 1
#
# 높이 `n`인 왼쪽 삼각형을 while로 반환하세요. (stars_left와 동일 출력)

# %%
def stars_left_while(n: int) -> str:
    # TODO
    pass


assert stars_left_while(3) == "*
**
***
"

# %% [markdown]
# ### [P4-15] (쉬움) 리스트 컴프리헨션 기초
#
# 0부터 n-1까지 중 2의 배수만 LC로 반환하세요. (while 파트지만 LC도 연습)
# - 힌트: range 사용

# %%
def multiples_of_two_lc(n: int) -> list[int]:
    # TODO
    pass


assert multiples_of_two_lc(7) == [0,2,4,6]

# %% [markdown]
# ### [P4-16] (쉬움) while로 문자열 chunk
#
# 문자열 `s`를 길이 `k`씩 끊어 리스트로 반환하세요. (Part3 chunk_string과 유사하지만 while로)

# %%
def chunk_string_while(s: str, k: int) -> list[str]:
    # TODO
    pass


assert chunk_string_while("abcde", 2) == ["ab","cd","e"]

# %% [markdown]
# ### [P4-17] (쉬움) 카운터 딕셔너리
#
# 리스트 `items`의 등장 횟수를 딕셔너리로 반환하세요. while 사용

# %%
def count_items(items: list) -> dict:
    # TODO
    pass


assert count_items(["a","b","a"]) == {"a":2,"b":1}

# %% [markdown]
# ### [P4-18] (쉬움) 문자열에서 숫자만
#
# 문자열 `s`에서 숫자만 남긴 문자열을 while로 반환하세요.

# %%
def keep_digits_while(s: str) -> str:
    # TODO
    pass


assert keep_digits_while("a1b2c3") == "123"

# %% [markdown]
# ### [P4-19] (쉬움) 최소 길이까지
#
# 두 문자열 `a`, `b`의 공통 접두사 길이를 반환하세요. while 사용
# - 예: ('flower','flow') -> 4

# %%
def common_prefix_len(a: str, b: str) -> int:
    # TODO
    pass


assert common_prefix_len("flower","flow") == 4
assert common_prefix_len("abc","xyz") == 0

# %% [markdown]
# ### [P4-20] (쉬움) 반전 not 2
#
# 문자열 `s`가 비어있지 **않으면** True를 반환하는 `not_empty(s)`를 작성하세요.
# - `not` 사용

# %%
def not_empty(s: str) -> bool:
    # TODO
    pass


assert not_empty("") is False
assert not_empty("x") is True

# %% [markdown]
# ### [P4-21] (응용) while로 문자열 뒤집기
#
# 문자열 `s`를 while로 뒤집어 반환하세요.

# %%
def reverse_str_while(s: str) -> str:
    # TODO
    pass


assert reverse_str_while("abc") == "cba"

# %% [markdown]
# ### [P4-22] (응용) 연속 공백 하나로
#
# 문자열 `s`에서 연속된 공백을 하나의 공백으로 줄여 반환하세요.
# - 예: 'a  b   c' -> 'a b c'

# %%
def squeeze_spaces(s: str) -> str:
    # TODO
    pass


assert squeeze_spaces("a  b   c") == "a b c"
assert squeeze_spaces("   a") == " a"

# %% [markdown]
# ### [P4-23] (응용) while로 필터
#
# 리스트 `nums`에서 10 이상인 값만 남긴 리스트를 while로 반환하세요.

# %%
def keep_ge_10(nums: list[int]) -> list[int]:
    # TODO
    pass


assert keep_ge_10([9,10,11]) == [10,11]

# %% [markdown]
# ### [P4-24] (응용) while + break 2
#
# 문자열 `s`에서 처음으로 숫자 문자를 만나면 그 인덱스를 반환하세요. 없으면 -1.

# %%
def first_digit_index(s: str) -> int:
    # TODO
    pass


assert first_digit_index("ab3c") == 2
assert first_digit_index("abc") == -1

# %% [markdown]
# ### [P4-25] (응용) while + continue 2
#
# 1부터 n까지 중 3의 배수는 건너뛰고 합을 반환하세요.

# %%
def sum_skip_multiples_of_three(n: int) -> int:
    # TODO
    pass


assert sum_skip_multiples_of_three(6) == 1+2+4+5

# %% [markdown]
# ### [P4-26] (응용) 반전 not 3
#
# 문자열 `s`에 모음이 하나도 없으면 True를 반환하세요.
# - `not` 사용

# %%
def no_vowel(s: str) -> bool:
    # TODO
    pass


assert no_vowel("rhythm") is True
assert no_vowel("code") is False

# %% [markdown]
# ### [P4-27] (응용) 별찍기 while 2
#
# 높이 n인 오른쪽 정렬 삼각형을 while로 반환하세요.

# %%
def stars_right_while(n: int) -> str:
    # TODO
    pass


assert stars_right_while(3) == '''  *
 **
***
'''

# %% [markdown]
# ### [P4-28] (응용) 별찍기 while 3
#
# 높이 n인 피라미드를 while로 반환하세요.

# %%
def stars_pyramid_while(n: int) -> str:
    # TODO
    pass


assert stars_pyramid_while(3) == '''  *
 ***
*****
'''

# %% [markdown]
# ### [P4-29] (응용) 문자열에서 알파벳만
#
# 문자열 `s`에서 알파벳(a-zA-Z)만 남긴 문자열을 반환하세요. while 사용

# %%
def keep_alpha(s: str) -> str:
    # TODO
    pass


assert keep_alpha("a1B2!") == "aB"

# %% [markdown]
# ### [P4-30] (응용) while로 최소값
#
# 비어있지 않은 리스트 `nums`의 최소값을 while로 반환하세요. (`min` 금지)

# %%
def min_manual_while(nums: list[int]) -> int:
    # TODO
    pass


assert min_manual_while([3,1,9,2]) == 1

# %% [markdown]
# ### [P4-31] (응용) 문자열 반복 패턴
#
# 문자열 `unit`을 반복해서 길이가 `n` 이상이 되면 그 문자열을 반환하세요.
# - 예: unit='ab', n=5 -> 'ababab'

# %%
def repeat_until_length(unit: str, n: int) -> str:
    # TODO
    pass


assert repeat_until_length("ab", 5) == "ababab"
assert repeat_until_length("x", 3) == "xxx"

# %% [markdown]
# ### [P4-32] (응용) 리스트에서 조건 첫 값
#
# 리스트 `nums`에서 5보다 큰 첫 값을 반환하세요. 없으면 None. while + break

# %%
def first_gt_5(nums: list[int]):
    # TODO
    pass


assert first_gt_5([1,3,6,2]) == 6
assert first_gt_5([1,2,3]) is None

# %% [markdown]
# ### [P4-33] (응용) 연속 문자 개수
#
# 문자열 `s`에서 처음 문자가 연속으로 몇 번 반복되는지 반환하세요.
# - 예: 'aaabb' -> 3, 'bba' -> 2

# %%
def first_run_length(s: str) -> int:
    # TODO
    pass


assert first_run_length("aaabb") == 3
assert first_run_length("bba") == 2

# %% [markdown]
# ### [P4-34] (응용) 접미사 제거
#
# 문자열 `s`가 접미사 `suffix`로 끝나면 그 부분을 제거해 반환, 아니면 원래 문자열 반환.
# - while로 직접 비교하지 말고 `endswith` 써도 됨, 대신 제거 과정은 슬라이싱 가능

# %%
def remove_suffix_if(s: str, suffix: str) -> str:
    # TODO
    pass


assert remove_suffix_if("hello.py", ".py") == "hello"
assert remove_suffix_if("hello.txt", ".py") == "hello.txt"

# %% [markdown]
# ### [P4-35] (응용) 문자열에서 연속 중복 제거
#
# 문자열 `s`에서 연속 중복 문자를 하나로 줄여 반환하세요.
# - 예: 'aaabcc' -> 'abc'

# %%
def dedup_consecutive(s: str) -> str:
    # TODO
    pass


assert dedup_consecutive("aaabcc") == "abc"
assert dedup_consecutive("") == ""

# %% [markdown]
# ### [P4-36] (응용) 리스트 컴프리헨션 8
#
# 리스트 `nums`에서 음수가 아닌 값만 남긴 새 리스트를 LC로 반환하세요.

# %%
def non_negative_lc(nums: list[int]) -> list[int]:
    # TODO
    pass


assert non_negative_lc([-1,0,2,-3]) == [0,2]

# %% [markdown]
# ### [P4-37] (응용) while로 문자열 교체
#
# 문자열 `s`에서 문자 `a`를 모두 `b`로 바꾼 문자열을 while로 반환하세요.
# - `replace` 금지

# %%
def replace_char_while(s: str, a: str, b: str) -> str:
    # TODO
    pass


assert replace_char_while("banana","a","o") == "bonono"

# %% [markdown]
# ### [P4-38] (응용) 반전 not 4
#
# 리스트 `nums`에 짝수가 하나라도 있으면 True. 없으면 False.
# - `not`을 이용해 '짝수가 하나도 없음'을 먼저 구해 반전해도 됨

# %%
def has_even(nums: list[int]) -> bool:
    # TODO
    pass


assert has_even([1,3,5]) is False
assert has_even([1,4,5]) is True

# %% [markdown]
# ### [P4-39] (응용) 끝나는 공백 제거
#
# 문자열 `s`의 끝에 있는 공백들을 제거한 문자열을 반환하세요. while 사용
# - `rstrip()` 금지

# %%
def rstrip_spaces(s: str) -> str:
    # TODO
    pass


assert rstrip_spaces("a  ") == "a"
assert rstrip_spaces("a b ") == "a b"

# %% [markdown]
# ### [P4-40] (응용) 조건 만족 시까지 증가
#
# 정수 `x`를 2씩 증가시키며 처음으로 10 이상이 되는 값을 반환하세요. while 사용

# %%
def bump_to_10(x: int) -> int:
    # TODO
    pass


assert bump_to_10(3) == 11
assert bump_to_10(10) == 10

# %% [markdown]
# ## Part 5. if문 (30문제)
# - `not` 반전 문제 다수 포함
# - 절댓값(abs) 문제 제거
# - 수학(약수/최대공약수) 제거

# %% [markdown]
# ### [P5-01] (쉬움) 양수/음수/0
#
# 정수 `n`이 양수면 'positive', 음수면 'negative', 0이면 'zero'를 반환하는 `sign_word(n)`를 작성하세요.

# %%
def sign_word(n: int) -> str:
    # TODO
    pass


assert sign_word(3) == "positive"
assert sign_word(-2) == "negative"
assert sign_word(0) == "zero"

# %% [markdown]
# ### [P5-02] (쉬움) 점수 등급
#
# 점수 `score`를 받아 A(90+), B(80+), C(70+), D(60+), F를 반환하세요.

# %%
def grade(score: int) -> str:
    # TODO
    pass


assert grade(95) == "A"
assert grade(80) == "B"
assert grade(72) == "C"
assert grade(60) == "D"
assert grade(10) == "F"

# %% [markdown]
# ### [P5-03] (쉬움) 홀짝
#
# 정수 `n`이 짝수면 'even', 홀수면 'odd'를 반환하세요.

# %%
def odd_even(n: int) -> str:
    # TODO
    pass


assert odd_even(2) == "even"
assert odd_even(3) == "odd"

# %% [markdown]
# ### [P5-04] (쉬움) 문자 카테고리
#
# 문자 `ch`가 숫자면 'digit', 알파벳이면 'alpha', 그 외면 'other'를 반환하세요.

# %%
def char_category(ch: str) -> str:
    # TODO
    pass


assert char_category("7") == "digit"
assert char_category("a") == "alpha"
assert char_category("Z") == "alpha"
assert char_category("!") == "other"

# %% [markdown]
# ### [P5-05] (쉬움) not 1
#
# 불리언 `flag`가 False일 때만 'blocked', 아니면 'ok'를 반환하세요. (`not` 사용)

# %%
def access(flag: bool) -> str:
    # TODO
    pass


assert access(True) == "ok"
assert access(False) == "blocked"

# %% [markdown]
# ### [P5-06] (쉬움) 비밀번호 길이
#
# 문자열 `pw`의 길이가 8 미만이면 'too short', 아니면 'ok'를 반환하세요.

# %%
def pw_check(pw: str) -> str:
    # TODO
    pass


assert pw_check("1234567") == "too short"
assert pw_check("12345678") == "ok"

# %% [markdown]
# ### [P5-07] (쉬움) 공백 포함 여부
#
# 문자열 `s`에 공백이 있으면 'has space', 없으면 'no space'를 반환하세요.

# %%
def space_status(s: str) -> str:
    # TODO
    pass


assert space_status("a b") == "has space"
assert space_status("ab") == "no space"

# %% [markdown]
# ### [P5-08] (쉬움) not 2
#
# 문자열 `s`에 'x'가 **없으면** True, 있으면 False를 반환하세요. (`not` 사용)

# %%
def no_x(s: str) -> bool:
    # TODO
    pass


assert no_x("abc") is True
assert no_x("axb") is False

# %% [markdown]
# ### [P5-09] (쉬움) 삼항 연산자
#
# 정수 `n`이 0 이상이면 'non-negative', 아니면 'negative'를 **삼항 연산자**로 반환하세요.

# %%
def nn_or_neg(n: int) -> str:
    # TODO
    pass


assert nn_or_neg(0) == "non-negative"
assert nn_or_neg(-1) == "negative"

# %% [markdown]
# ### [P5-10] (쉬움) 할인 적용
#
# `price`가 10000 이상이면 10% 할인한 가격을 반환, 아니면 그대로 반환하세요.

# %%
def apply_discount(price: int) -> int:
    # TODO
    pass


assert apply_discount(10000) == 9000
assert apply_discount(9999) == 9999

# %% [markdown]
# ### [P5-11] (쉬움) 문자열 선택
#
# 문자열 `a`, `b` 중 더 긴 문자열을 반환하세요. 길이가 같으면 `a` 반환.

# %%
def longer(a: str, b: str) -> str:
    # TODO
    pass


assert longer("hi", "hello") == "hello"
assert longer("aa", "bb") == "aa"

# %% [markdown]
# ### [P5-12] (쉬움) 리스트 길이 분류
#
# 리스트 `arr`의 길이가 0이면 'empty', 1~3이면 'small', 그 외면 'large'를 반환하세요.
# - 빈 컨테이너 비교(==[])는 쓰지 말고 `len(arr)` 사용

# %%
def size_label(arr: list) -> str:
    # TODO
    pass


assert size_label([]) == "empty"
assert size_label([1]) == "small"
assert size_label([1,2,3]) == "small"
assert size_label([1,2,3,4]) == "large"

# %% [markdown]
# ### [P5-13] (쉬움) not 3
#
# 정수 `n`이 10 이상이 **아니면** 'low', 아니면 'high'를 반환하세요. (`not` 사용)

# %%
def low_high(n: int) -> str:
    # TODO
    pass


assert low_high(9) == "low"
assert low_high(10) == "high"

# %% [markdown]
# ### [P5-14] (쉬움) 알파벳 여부
#
# 문자 `ch`가 알파벳이면 True, 아니면 False.

# %%
def is_alpha(ch: str) -> bool:
    # TODO
    pass


assert is_alpha("a") is True
assert is_alpha("Z") is True
assert is_alpha("1") is False

# %% [markdown]
# ### [P5-15] (쉬움) 단어 포함
#
# 문장 `s`에 단어 `word`가 포함되면 True, 아니면 False.
# - 단순 포함(`in`)으로 처리

# %%
def contains_word(s: str, word: str) -> bool:
    # TODO
    pass


assert contains_word("python is fun", "python") is True
assert contains_word("python is fun", "java") is False

# %% [markdown]
# ### [P5-16] (응용) shipping_fee
#
# 가격 `price`와 회원 여부 `is_member`에 따라 배송비를 반환하세요.
# - 회원이면 항상 0
# - 비회원이면 price >= 30000이면 0, 아니면 3000

# %%
def shipping_fee(price: int, is_member: bool) -> int:
    # TODO
    pass


assert shipping_fee(10000, True) == 0
assert shipping_fee(40000, False) == 0
assert shipping_fee(10000, False) == 3000

# %% [markdown]
# ### [P5-17] (응용) login_result
#
# 아이디 `uid`, 비밀번호 `pw`가 주어질 때 결과를 반환하세요.
# - uid가 빈 문자열이면 'no id'
# - pw가 빈 문자열이면 'no pw'
# - 둘 다 있으면 'ok'
# - `not` 사용 권장

# %%
def login_result(uid: str, pw: str) -> str:
    # TODO
    pass


assert login_result("", "x") == "no id"
assert login_result("u", "") == "no pw"
assert login_result("u", "p") == "ok"

# %% [markdown]
# ### [P5-18] (응용) triangle_possible
#
# 세 변 a,b,c가 삼각형이 될 수 있으면 True.
# - (가장 긴 변) < (나머지 두 변의 합) 이어야 함
# - 리스트 정렬 없이 if로 처리해도 됨

# %%
def triangle_possible(a: int, b: int, c: int) -> bool:
    # TODO
    pass


assert triangle_possible(3,4,5) is True
assert triangle_possible(1,2,3) is False

# %% [markdown]
# ### [P5-19] (응용) caps_if_short
#
# 문자열 `s`의 길이가 5 이하이면 대문자로 반환, 아니면 그대로 반환.

# %%
def caps_if_short(s: str) -> str:
    # TODO
    pass


assert caps_if_short("hi") == "HI"
assert caps_if_short("python") == "python"

# %% [markdown]
# ### [P5-20] (응용) not 4
#
# 정수 `n`이 0이 아니면 True, 0이면 False를 반환하세요. (`not` 사용)

# %%
def is_nonzero(n: int) -> bool:
    # TODO
    pass


assert is_nonzero(0) is False
assert is_nonzero(5) is True

# %% [markdown]
# ### [P5-21] (응용) vowel_or_not
#
# 문자 `ch`가 모음(a,e,i,o,u)이면 'vowel', 아니면 'consonant' 반환.
# - ch는 소문자 알파벳 1글자

# %%
def vowel_or_not(ch: str) -> str:
    # TODO
    pass


assert vowel_or_not("a") == "vowel"
assert vowel_or_not("b") == "consonant"

# %% [markdown]
# ### [P5-22] (응용) ticket_price
#
# 나이 `age`에 따라 가격을 반환하세요.
# - 0~6: 0
# - 7~18: 5000
# - 19~64: 10000
# - 65+: 0

# %%
def ticket_price(age: int) -> int:
    # TODO
    pass


assert ticket_price(5) == 0
assert ticket_price(10) == 5000
assert ticket_price(30) == 10000
assert ticket_price(70) == 0

# %% [markdown]
# ### [P5-23] (응용) password_strength
#
# 비밀번호 `pw` 강도를 반환하세요.
# - 길이 < 8: 'weak'
# - 길이 >= 8 이고 숫자 포함: 'good'
# - 길이 >= 8 이지만 숫자 없음: 'medium'

# %%
def password_strength(pw: str) -> str:
    # TODO
    pass


assert password_strength("abcdefg") == "weak"
assert password_strength("abcdefgh") == "medium"
assert password_strength("abcd1234") == "good"

# %% [markdown]
# ### [P5-24] (응용) weekday_or_weekend
#
# 요일 문자열 `day`가 'sat' 또는 'sun'이면 'weekend' 아니면 'weekday'.
# - 소문자 3글자

# %%
def weekday_or_weekend(day: str) -> str:
    # TODO
    pass


assert weekday_or_weekend("sat") == "weekend"
assert weekday_or_weekend("mon") == "weekday"

# %% [markdown]
# ### [P5-25] (응용) not 5
#
# 문자열 `s`가 빈 문자열이 **아니면** True를 반환하세요. (`not` 사용)
# - 빈 컨테이너 비교 대신 `len(s)` 사용 가능

# %%
def has_text(s: str) -> bool:
    # TODO
    pass


assert has_text("") is False
assert has_text(" ") is True

# %% [markdown]
# ### [P5-26] (응용) clamp_0_100
#
# 정수 `x`를 0~100 범위로 제한(clamp)해서 반환하세요.
# - x<0 -> 0, x>100 -> 100, 그 외 -> x

# %%
def clamp_0_100(x: int) -> int:
    # TODO
    pass


assert clamp_0_100(-1) == 0
assert clamp_0_100(50) == 50
assert clamp_0_100(101) == 100

# %% [markdown]
# ### [P5-27] (응용) safe_divide
#
# 두 수 `a`, `b`에 대해 b가 0이면 None, 아니면 a/b를 반환하세요.

# %%
def safe_divide(a: float, b: float):
    # TODO
    pass


assert safe_divide(10, 2) == 5
assert safe_divide(10, 0) is None

# %% [markdown]
# ### [P5-28] (응용) choose_message
#
# 불리언 `is_admin`과 `is_active`에 따라 메시지 반환.
# - 비활성(is_active False)이면 항상 'inactive'
# - 활성이고 admin이면 'admin'
# - 활성이고 admin 아니면 'user'
# - `not` 사용

# %%
def choose_message(is_admin: bool, is_active: bool) -> str:
    # TODO
    pass


assert choose_message(True, False) == "inactive"
assert choose_message(True, True) == "admin"
assert choose_message(False, True) == "user"

# %% [markdown]
# ### [P5-29] (응용) compare_lengths
#
# 문자열 `a`, `b` 길이를 비교해 'a', 'b', 'same' 중 하나를 반환하세요.

# %%
def compare_lengths(a: str, b: str) -> str:
    # TODO
    pass


assert compare_lengths("hi","hello") == "b"
assert compare_lengths("hello","hi") == "a"
assert compare_lengths("aa","bb") == "same"

# %% [markdown]
# ### [P5-30] (응용) is_valid_email_simple
#
# 아주 단순한 이메일 검증: 문자열 `s`에 `'@'`가 정확히 1개이고, `'@'` 앞뒤로 문자가 최소 1개씩 있으면 True.
# - split 사용 가능

# %%
def is_valid_email_simple(s: str) -> bool:
    # TODO
    pass


assert is_valid_email_simple("a@b") is True
assert is_valid_email_simple("@b") is False
assert is_valid_email_simple("a@") is False
assert is_valid_email_simple("a@@b") is False

# %% [markdown]
# ## Part 6. if / for문 복합문제 (50문제)
# - 기존 20 + 추가 10 + 추가 복합 20 반영
# - `input()` 없이 **매개변수로 입력을 받는 함수**로 풀이
# - 문자열/리스트 처리 중심, 수학(약수/최대공약수/피보나치/팩토리얼) 제거
# - 리스트 컴프리헨션/별찍기 포함

# %% [markdown]
# ### [P6-01] (쉬움) remove_vowels
#
# 문자열에서 모음(a,e,i,o,u)을 제거한 문자열을 반환하는 함수 `remove_vowels(s)`를 작성하세요.
# - 공백은 유지
# - 예: 'codeit' -> 'cdt'

# %%
def remove_vowels(s: str) -> str:
    # TODO
    pass


assert remove_vowels("codeit") == "cdt"
assert remove_vowels("python programming") == "pythn prgrmmng"

# %% [markdown]
# ### [P6-02] (쉬움) check_obesity
#
# 키(cm)와 몸무게(kg)를 받아 BMI 기준으로 비만도를 반환하는 `check_obesity(height_cm, weight_kg)`를 작성하세요.
# - BMI = kg / (m^2)
# - 18.5 미만: '저체중'
# - 18.5 이상 23 미만: '정상'
# - 23 이상 25 미만: '과체중'
# - 25 이상: '비만'
# - **input 사용 금지**

# %%
def check_obesity(height_cm: float, weight_kg: float) -> str:
    # TODO
    pass


assert check_obesity(175, 60) == "정상"
assert check_obesity(180, 88) == "비만"

# %% [markdown]
# ### [P6-03] (쉬움) count_vowels
#
# 문자열 `s`의 모음 개수를 반환하세요.

# %%
def count_vowels(s: str) -> int:
    # TODO
    pass


assert count_vowels("codeit") == 3  # o,e,i
assert count_vowels("rhythm") == 0

# %% [markdown]
# ### [P6-04] (쉬움) only_digits
#
# 문자열 `s`가 숫자만으로 이루어져 있으면 True, 아니면 False.
# - 빈 문자열은 False

# %%
def only_digits(s: str) -> bool:
    # TODO
    pass


assert only_digits("123") is True
assert only_digits("12a") is False
assert only_digits("") is False

# %% [markdown]
# ### [P6-05] (쉬움) filter_short_words
#
# 단어 리스트 `words`에서 길이 2 이하인 단어만 남긴 리스트를 반환하세요. (for + if)

# %%
def filter_short_words(words: list[str]) -> list[str]:
    # TODO
    pass


assert filter_short_words(["a","to","you","ok"]) == ["a","to","ok"]

# %% [markdown]
# ### [P6-06] (쉬움) sum_positive_only
#
# 정수 리스트 `nums`에서 양수만 더한 합을 반환하세요.

# %%
def sum_positive_only(nums: list[int]) -> int:
    # TODO
    pass


assert sum_positive_only([-1,2,0,3]) == 5

# %% [markdown]
# ### [P6-07] (쉬움) replace_vowels_with_star
#
# 문자열 `s`에서 모음을 `*`로 바꾼 문자열을 반환하세요.

# %%
def replace_vowels_with_star(s: str) -> str:
    # TODO
    pass


assert replace_vowels_with_star("codeit") == "c*d**t"

# %% [markdown]
# ### [P6-08] (쉬움) count_long_words
#
# 문자열 리스트 `words`에서 길이 5 이상인 단어 개수를 반환하세요.

# %%
def count_long_words(words: list[str]) -> int:
    # TODO
    pass


assert count_long_words(["python","is","very","funny"]) == 1

# %% [markdown]
# ### [P6-09] (쉬움) first_non_space
#
# 문자열 `s`에서 공백이 아닌 첫 문자를 반환하세요. 전부 공백이면 None.
# - for + if + break

# %%
def first_non_space(s: str):
    # TODO
    pass


assert first_non_space("   a") == "a"
assert first_non_space("   ") is None

# %% [markdown]
# ### [P6-10] (쉬움) censor_word
#
# 문장 `s`에서 `bad`라는 단어(부분 문자열)를 전부 '***'로 바꿔 반환하세요.
# - `replace` 사용 가능

# %%
def censor_word(s: str) -> str:
    # TODO
    pass


assert censor_word("bad apple") == "*** apple"
assert censor_word("notbad") == "not***"

# %% [markdown]
# ### [P6-11] (쉬움) split_even_odd
#
# 정수 리스트 `nums`를 받아 짝수 리스트와 홀수 리스트를 `(evens, odds)`로 반환하세요.

# %%
def split_even_odd(nums: list[int]) -> tuple[list[int], list[int]]:
    # TODO
    pass


assert split_even_odd([1,2,3,4]) == ([2,4],[1,3])

# %% [markdown]
# ### [P6-12] (쉬움) stars_box_border
#
# 가로 `w`, 세로 `h`인 테두리만 별('*')로 그린 문자열을 반환하세요.
# - 내부는 공백
# - w,h는 2 이상
# - 예: w=4,h=3
# ```
# ****
# *  *
# ****
# ```

# %%
def stars_box_border(w: int, h: int) -> str:
    # TODO
    pass


assert stars_box_border(4,3) == "****
*  *
****
"

# %% [markdown]
# ### [P6-13] (쉬움) lc_filter_vowels
#
# 문자열 `s`에서 자음만 모아 문자열로 반환하세요. (리스트 컴프리헨션 사용 권장)

# %%
def consonants_only(s: str) -> str:
    # TODO
    pass


assert consonants_only("codeit") == "cdt"

# %% [markdown]
# ### [P6-14] (쉬움) not_all_upper
#
# 문자열 `s`가 모두 대문자인 것이 **아니면** True를 반환하세요.
# - `not` 사용

# %%
def not_all_upper(s: str) -> bool:
    # TODO
    pass


assert not_all_upper("ABC") is False
assert not_all_upper("AbC") is True

# %% [markdown]
# ### [P6-15] (쉬움) count_char_case_insensitive
#
# 문자열 `s`에서 문자 `ch`가 몇 번 나오는지(대소문자 무시) 반환하세요.

# %%
def count_char_ci(s: str, ch: str) -> int:
    # TODO
    pass


assert count_char_ci("AaAa", "a") == 4

# %% [markdown]
# ### [P6-16] (쉬움) remove_consecutive_spaces
#
# 문자열 `s`에서 연속된 공백을 하나로 줄여 반환하세요. (for + if)
# - 예: 'a  b   c' -> 'a b c'

# %%
def remove_consecutive_spaces(s: str) -> str:
    # TODO
    pass


assert remove_consecutive_spaces("a  b   c") == "a b c"

# %% [markdown]
# ### [P6-17] (쉬움) list_to_sentence
#
# 단어 리스트 `words`를 공백으로 이어 문장으로 반환하세요.
# - 빈 리스트면 ''

# %%
def list_to_sentence(words: list[str]) -> str:
    # TODO
    pass


assert list_to_sentence(["python","is","fun"]) == "python is fun"
assert list_to_sentence([]) == ""

# %% [markdown]
# ### [P6-18] (쉬움) find_all_indices
#
# 문자열 `s`에서 문자 `ch`가 나오는 모든 인덱스를 리스트로 반환하세요.
# - `enumerate` 금지

# %%
def find_all_indices(s: str, ch: str) -> list[int]:
    # TODO
    pass


assert find_all_indices("banana","a") == [1,3,5]

# %% [markdown]
# ### [P6-19] (쉬움) remove_shorter_than
#
# 리스트 `words`에서 길이가 `k` 미만인 단어를 제거한 새 리스트를 반환하세요.

# %%
def remove_shorter_than(words: list[str], k: int) -> list[str]:
    # TODO
    pass


assert remove_shorter_than(["a","to","you","python"], 3) == ["you","python"]

# %% [markdown]
# ### [P6-20] (쉬움) count_true
#
# 불리언 리스트 `flags`에서 True의 개수를 반환하세요.

# %%
def count_true(flags: list[bool]) -> int:
    # TODO
    pass


assert count_true([True, False, True, True]) == 3

# %% [markdown]
# ### [P6-21] (쉬움) toggle_case_letters_only
#
# 문자열 `s`에서 알파벳만 대소문자를 뒤집고, 다른 문자는 그대로 두세요.
# - 예: 'a1B!' -> 'A1b!'

# %%
def toggle_case_letters_only(s: str) -> str:
    # TODO
    pass


assert toggle_case_letters_only("a1B!") == "A1b!"

# %% [markdown]
# ### [P6-22] (쉬움) prefix_until_char
#
# 문자열 `s`에서 문자 `stop`을 만나기 전까지의 접두사를 반환하세요.
# - stop이 없으면 전체 반환

# %%
def prefix_until_char(s: str, stop: str) -> str:
    # TODO
    pass


assert prefix_until_char("abc#def", "#") == "abc"
assert prefix_until_char("abcdef", "#") == "abcdef"

# %% [markdown]
# ### [P6-23] (쉬움) lc_square_odds
#
# 정수 리스트 `nums`에서 홀수만 제곱한 리스트를 반환하세요. (리스트 컴프리헨션)

# %%
def square_odds_lc(nums: list[int]) -> list[int]:
    # TODO
    pass


assert square_odds_lc([1,2,3,4,5]) == [1,9,25]

# %% [markdown]
# ### [P6-24] (쉬움) stars_diagonal
#
# 정사각형 크기 `n`에서 대각선만 '*'로 찍은 문자열을 반환하세요.
# - 나머지는 '.'
# - n=3:
# ```
# *..
# .*.
# ..*
# ```

# %%
def stars_diagonal(n: int) -> str:
    # TODO
    pass


assert stars_diagonal(3) == '''*..
.*.
..*
'''

# %% [markdown]
# ### [P6-25] (쉬움) not_contains_any
#
# 문자열 `s`에 금지 문자들 `banned`(리스트)가 하나도 포함되어 있지 않으면 True.
# - `not` 사용

# %%
def not_contains_any(s: str, banned: list[str]) -> bool:
    # TODO
    pass


assert not_contains_any("hello", ["x","y"]) is True
assert not_contains_any("hello", ["e","x"]) is False

# %% [markdown]
# ### [P6-26] (응용) rle_encode
#
# 문자열 `s`를 런-길이 인코딩(RLE)으로 압축해 반환하세요.
# - 연속된 같은 문자를 '문자+개수'로 표현
# - 예: 'aaabb' -> 'a3b2'
# - 빈 문자열이면 ''

# %%
def rle_encode(s: str) -> str:
    # TODO
    pass


assert rle_encode("") == ""
assert rle_encode("aaabb") == "a3b2"
assert rle_encode("abcd") == "a1b1c1d1"

# %% [markdown]
# ### [P6-27] (응용) rle_decode
#
# RLE로 인코딩된 문자열 `s`를 디코딩해 반환하세요.
# - 입력은 항상 올바른 형태(문자 다음에 1자리 이상 숫자)
# - 예: 'a3b2' -> 'aaabb'

# %%
def rle_decode(s: str) -> str:
    # TODO
    pass


assert rle_decode("a3b2") == "aaabb"
assert rle_decode("x1y2") == "xyy"

# %% [markdown]
# ### [P6-28] (응용) caesar_shift
#
# 영어 소문자만 있는 문자열 `s`를 시저 암호로 `k`만큼 오른쪽으로 밀어 반환하세요.
# - 'z' 다음은 'a'
# - 공백은 없다고 가정
# - 예: s='xyz', k=2 -> 'zab'

# %%
def caesar_shift(s: str, k: int) -> str:
    # TODO
    pass


assert caesar_shift("xyz", 2) == "zab"
assert caesar_shift("abc", 1) == "bcd"

# %% [markdown]
# ### [P6-29] (응용) title_case_simple
#
# 문장 `s`를 단어 단위로 첫 글자만 대문자로 바꿔 반환하세요.
# - 연속 공백은 단일 공백으로 먼저 줄여도 됨

# %%
def title_case_simple(s: str) -> str:
    # TODO
    pass


assert title_case_simple("python programming") == "Python Programming"
assert title_case_simple("  hello   world ") == "Hello World"

# %% [markdown]
# ### [P6-30] (응용) snake_to_camel
#
# snake_case 문자열 `s`를 camelCase로 변환하세요.
# - 예: 'hello_world' -> 'helloWorld'
# - '_'가 없을 수도 있음

# %%
def snake_to_camel(s: str) -> str:
    # TODO
    pass


assert snake_to_camel("hello_world") == "helloWorld"
assert snake_to_camel("already") == "already"

# %% [markdown]
# ### [P6-31] (응용) camel_to_snake
#
# camelCase 문자열 `s`를 snake_case로 변환하세요.
# - 예: 'helloWorld' -> 'hello_world'
# - 대문자 앞에 '_' 추가 후 소문자

# %%
def camel_to_snake(s: str) -> str:
    # TODO
    pass


assert camel_to_snake("helloWorld") == "hello_world"
assert camel_to_snake("myHTTPServer") == "my_h_t_t_p_server"

# %% [markdown]
# ### [P6-32] (응용) balanced_parentheses
#
# 문자열 `s`의 괄호()가 균형 잡혔으면 True.
# - '('는 +1, ')'는 -1
# - 중간에 음수가 되면 False
# - 마지막에 0이면 True

# %%
def balanced_parentheses(s: str) -> bool:
    # TODO
    pass


assert balanced_parentheses("(())") is True
assert balanced_parentheses("(()") is False
assert balanced_parentheses("())(") is False

# %% [markdown]
# ### [P6-33] (응용) remove_duplicates_sorted
#
# 정렬된 리스트 `nums`에서 중복을 제거한 새 리스트를 반환하세요.
# - 예: [1,1,2,2,2,3] -> [1,2,3]

# %%
def remove_duplicates_sorted(nums: list[int]) -> list[int]:
    # TODO
    pass


assert remove_duplicates_sorted([1,1,2,2,2,3]) == [1,2,3]
assert remove_duplicates_sorted([]) == []

# %% [markdown]
# ### [P6-34] (응용) two_sum_exists
#
# 정수 리스트 `nums`에 대해 서로 다른 두 원소의 합이 `target`이 되는 쌍이 존재하면 True.
# - O(n^2) 이중 for 허용

# %%
def two_sum_exists(nums: list[int], target: int) -> bool:
    # TODO
    pass


assert two_sum_exists([1,2,3,4], 5) is True  # 1+4
assert two_sum_exists([1,2,3,4], 10) is False

# %% [markdown]
# ### [P6-35] (응용) group_by_length
#
# 단어 리스트 `words`를 길이별로 묶은 딕셔너리를 반환하세요.
# - 예: ['a','to','you'] -> {1:['a'],2:['to'],3:['you']}

# %%
def group_by_length(words: list[str]) -> dict[int, list[str]]:
    # TODO
    pass


assert group_by_length(["a","to","you"]) == {1:["a"],2:["to"],3:["you"]}

# %% [markdown]
# ### [P6-36] (응용) top_char
#
# 문자열 `s`에서 가장 많이 등장한 문자를 반환하세요.
# - 동률이면 먼저 등장한 문자를 반환

# %%
def top_char(s: str) -> str:
    # TODO
    pass


assert top_char("abbaa") == "a"
assert top_char("abc") == "a"

# %% [markdown]
# ### [P6-37] (응용) compress_words
#
# 문장 `s`에서 각 단어를 '첫글자+길이' 형태로 바꿔 반환하세요.
# - 예: 'python is fun' -> 'p6 i2 f3'

# %%
def compress_words(s: str) -> str:
    # TODO
    pass


assert compress_words("python is fun") == "p6 i2 f3"

# %% [markdown]
# ### [P6-38] (응용) anagram_check
#
# 두 문자열 `a`, `b`가 애너그램이면 True.
# - 공백은 없다고 가정
# - 소문자 알파벳만
# - 정렬 사용 가능

# %%
def anagram_check(a: str, b: str) -> bool:
    # TODO
    pass


assert anagram_check("listen","silent") is True
assert anagram_check("hello","bello") is False

# %% [markdown]
# ### [P6-39] (응용) word_freq
#
# 문장 `s`의 단어 빈도를 딕셔너리로 반환하세요.
# - 공백 기준 split, 모두 소문자로 처리

# %%
def word_freq(s: str) -> dict[str,int]:
    # TODO
    pass


assert word_freq("A a B") == {"a":2,"b":1}

# %% [markdown]
# ### [P6-40] (응용) remove_stopwords
#
# 단어 리스트 `words`에서 금지 단어 `stop`(리스트)에 포함된 단어를 제거한 새 리스트를 반환하세요.
# - 대소문자 구분 없이 처리

# %%
def remove_stopwords(words: list[str], stop: list[str]) -> list[str]:
    # TODO
    pass


assert remove_stopwords(["I","love","Python"], ["i"]) == ["love","Python"]

# %% [markdown]
# ### [P6-41] (응용) mirror_words
#
# 단어 리스트 `words`를 받아 각 단어를 뒤집은 새 리스트를 반환하세요.
# - 예: ['ab','cd'] -> ['ba','dc']

# %%
def mirror_words(words: list[str]) -> list[str]:
    # TODO
    pass


assert mirror_words(["ab","cd"]) == ["ba","dc"]

# %% [markdown]
# ### [P6-42] (응용) stars_diamond_full
#
# 홀수 높이 `n`(예: 5,7)을 받아 다이아몬드 별을 문자열로 반환하세요.
# - n=5:
# ```
#   *
#  ***
# *****
#  ***
#   *
# ```

# %%
def stars_diamond_full(n: int) -> str:
    # TODO
    pass


assert stars_diamond_full(1) == "*
"
assert stars_diamond_full(5) == "  *
 ***
*****
 ***
  *
"

# %% [markdown]
# ### [P6-43] (응용) validate_password_rules
#
# 비밀번호 `pw`가 다음 규칙을 모두 만족하면 True.
# - 길이 8 이상
# - 공백 없음
# - 숫자 1개 이상 포함
# - 알파벳 1개 이상 포함

# %%
def validate_password_rules(pw: str) -> bool:
    # TODO
    pass


assert validate_password_rules("abcd1234") is True
assert validate_password_rules("abcd 1234") is False
assert validate_password_rules("abcdefgh") is False
assert validate_password_rules("12345678") is False

# %% [markdown]
# ### [P6-44] (응용) not_banned_start
#
# 문자열 `s`가 금지 접두사 리스트 `banned_prefixes` 중 어떤 것으로도 시작하지 않으면 True.
# - `not` 사용

# %%
def not_banned_start(s: str, banned_prefixes: list[str]) -> bool:
    # TODO
    pass


assert not_banned_start("python", ["java","c"]) is True
assert not_banned_start("code", ["co"]) is False

# %% [markdown]
# ### [P6-45] (응용) matrix_count_gt
#
# 2차원 리스트 `grid`에서 `threshold`보다 큰 값의 개수를 반환하세요.

# %%
def matrix_count_gt(grid: list[list[int]], threshold: int) -> int:
    # TODO
    pass


assert matrix_count_gt([[1,5],[7,2]], 4) == 2

# %% [markdown]
# ### [P6-46] (응용) email_mask
#
# 이메일 `s`에서 @ 앞의 아이디를 마스킹하세요.
# - 아이디 첫 글자와 마지막 글자는 남기고 가운데는 '*'로
# - 아이디 길이가 2 이하면 첫 글자만 남기고 나머지 '*' 처리
# - 예: 'abcd@x.com' -> 'a**d@x.com'

# %%
def email_mask(s: str) -> str:
    # TODO
    pass


assert email_mask("abcd@x.com") == "a**d@x.com"
assert email_mask("ab@x.com") == "a*@x.com"

# %% [markdown]
# ### [P6-47] (응용) merge_alternate
#
# 두 문자열 `a`, `b`를 번갈아가며 합친 문자열을 반환하세요.
# - 남는 부분은 뒤에 그대로 붙이기
# - 예: ('abc','XYZW') -> 'aXbYcZW'

# %%
def merge_alternate(a: str, b: str) -> str:
    # TODO
    pass


assert merge_alternate("abc","XYZW") == "aXbYcZW"
assert merge_alternate("","ab") == "ab"

# %% [markdown]
# ### [P6-48] (응용) remove_every_kth
#
# 리스트 `arr`에서 k번째(1-indexed) 원소마다 제거한 새 리스트를 반환하세요.
# - 예: arr=[1,2,3,4,5,6], k=2 -> [1,3,5]

# %%
def remove_every_kth(arr: list, k: int) -> list:
    # TODO
    pass


assert remove_every_kth([1,2,3,4,5,6], 2) == [1,3,5]
assert remove_every_kth([1,2,3], 5) == [1,2,3]

# %% [markdown]
# ### [P6-49] (응용) palindrome_ignore_spaces
#
# 문자열 `s`가 공백을 무시했을 때 회문이면 True.
# - 대소문자는 그대로 구분하지 말고 소문자로 통일해서 비교

# %%
def palindrome_ignore_spaces(s: str) -> bool:
    # TODO
    pass


assert palindrome_ignore_spaces("never odd or even") is True
assert palindrome_ignore_spaces("python") is False

# %% [markdown]
# ### [P6-50] (응용) lc_transform_sentence
#
# 문장 `s`의 각 단어를 대문자로 바꾼 문장을 반환하세요.
# - 리스트 컴프리헨션 + join 사용

# %%
def upper_words_sentence(s: str) -> str:
    # TODO
    pass


assert upper_words_sentence("python is fun") == "PYTHON IS FUN"
