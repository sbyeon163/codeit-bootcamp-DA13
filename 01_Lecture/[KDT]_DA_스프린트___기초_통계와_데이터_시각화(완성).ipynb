# %% [markdown]
# # 기초 통계와 데이터 시각화

# %% [markdown]
# **통계**
#
# - 상황을 쉽게 이해하도록 숫자로 정리하는 것
#
# **통계의 두 가지 분야: 기술 통계 vs 추론 통계**
#
# - 기술 통계(descriptive statistics): 데이터 요약, 핵심 특징 파악 -> 이 토픽에서 중점적으로 학습할 통계
# - 추론 통계(inferential statistics): 표본을 바탕으로 모집단을 추론
#   - 모집단을 직접 조사하려면 시간과 비용이 많이 들기 때문에 표본을 통해 모집단을 추론하는 것이 추론 통계의 핵심
#
# **모집단 vs 표본**
#
# - 모집단(population): 분석 대상이 되는 전체 집단
# - 표본(sample): 모집단에서 일부를 추출한 데이터
#
# **시각화**
#
# - 시각화: 데이터를 이해하기 쉽게 그림으로 표현
# - 시각화 목적: (1) 분석 과정에서 활용 (2) 분석 결과 전달
#
# **대표적인 파이썬 시각화 라이브러리 비교**
#
# | 라이브러리 | 특징 | 장점 | 단점 |
# |-----------|------|------|------|
# | **matplotlib** | 파이썬의 대표적인 범용 시각화 라이브러리 | 다양한 기본 그래프 제공, 커스터마이징 자유로움 | 코드가 길어질 수 있음 |
# | **seaborn** | matplotlib 기반의 고급 시각화 라이브러리 | 통계 시각화에 최적화, 보기 좋은 기본 스타일 제공 | matplotlib보다 세밀한 제어가 어려울 수 있음 |

# %% [markdown]
# # [1] 기술 통계

# %% [markdown]
# **기술 통계량(Descriptive Statistics)** : 데이터를 요약·설명하는 값들
#
# (1) 평균(mean): 데이터 합계 ÷ 데이터 개수
#
# (2) 중앙값(median): 데이터를 정렬했을 때 중앙에 위치한 값(짝수 개면 가운데 두 값의 평균)
#
# (3) 사분위수(quartiles): 데이터를 4등분한 값. Q1(25%)/Q2(50%, 중간값)/Q3(75%)/Q4(100%, 최댓값)
#
# (4) 최빈값(mode): 가장 자주 등장하는 값
#
# **데이터 유형**
# - 수치형(numerical) : 사칙연산 가능, 크기 비교 가능
# - 범주형(categorical) : 최빈값/종류 수 파악 가능

# %%
# 라이브러리 불러오기
import pandas as pd

# %%
# 데이터 불러오기
exam_df = pd.read_csv("/content/exam.csv")
exam_df.head()
# Out:
#    math_score  science_score  english_score second_lang
# 0        45.0           68.0           68.0     Chinese
# 1        80.0           44.0           78.0    Japanese
# 2        37.5           50.0           78.0     Chinese
# 3        57.5           56.0           78.0     Russian
# 4        45.0           68.0           82.0     Chinese

# %%
exam_df.shape
# Out:
# (200, 4)

# %% [markdown]
# - `describe`: 컬럼별로 기본적인 통계 정보 확인 가능하고, `describe`은 수치형 데이터에 대해서 계산

# %%
exam_df.describe()
# Out:
#        math_score  science_score  english_score
# count  200.000000      200.00000     200.000000
# mean    52.830000       54.98750      77.547500
# std     12.961912        9.42178       9.165507
# min     15.000000       20.00000      25.000000
# 25%     45.000000       48.00000      72.000000
# 50%     52.500000       56.00000      78.000000
# 75%     60.000000       62.00000      84.000000
# max     95.000000       90.00000      94.000000

# %% [markdown]
# - `describe`: 컬럼별로 기본적인 통계 정보 확인 가능하고, `describe`은 수치형 데이터에 대해서 계산
#   - `include='all'`: 수치형 데이터 포함 모든 데이터 유형에 대해서 보고 싶을 때
#   - `top`(최빈값), `freq`(최빈값 등장 횟수)

# %%
# 범주의 종류
exam_df['second_lang'].unique()
# Out:
# array(['Chinese', 'Japanese', 'Russian', 'German', 'French'], dtype=object)

# %%
# 범주의 종류의 개수
exam_df['second_lang'].nunique()
# Out:
# 5

# %%
exam_df.describe(include='all')
# Out:
#         math_score  science_score  english_score second_lang
# count   200.000000      200.00000     200.000000         200
# unique         NaN            NaN            NaN           5
# top            NaN            NaN            NaN     Chinese
# freq           NaN            NaN            NaN          65
# mean     52.830000       54.98750      77.547500         NaN
# std      12.961912        9.42178       9.165507         NaN
# min      15.000000       20.00000      25.000000         NaN
# 25%      45.000000       48.00000      72.000000         NaN
# 50%      52.500000       56.00000      78.000000         NaN
# 75%      60.000000       62.00000      84.000000         NaN
# max      95.000000       90.00000      94.000000         NaN

# %% [markdown]
# ## 평균 vs 중앙값
#
# **평균 vs 중앙값**
#
# - 평균과 중앙값은 모두 대표값이지만, 이상치가 있을 때는 중앙값이 더 안정적인 지표
#
# **이상치(outlier)**
#
# - 데이터 집합에서 다른 값들과 비교해 현저히 크거나 작은 값
# - 이상치 발생 원인
#
#   (1) 오류 : 잘못 입력된 값
#
#   (2) 극단값 : 실제로 매우 특이한 값

# %% [markdown]
# ### 실습) 통계 기본 상식
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8288)

# %%
exam_df.describe()
# Out:
#        math_score  science_score  english_score
# count  200.000000      200.00000     200.000000
# mean    52.830000       54.98750      77.547500
# std     12.961912        9.42178       9.165507
# min     15.000000       20.00000      25.000000
# 25%     45.000000       48.00000      72.000000
# 50%     52.500000       56.00000      78.000000
# 75%     60.000000       62.00000      84.000000
# max     95.000000       90.00000      94.000000

# %%
exam_df['math_score'].mode()
# Out:
# 0    55.0
# Name: math_score, dtype: float64

# %%
exam_df.describe(include='all')
# Out:
#         math_score  science_score  english_score second_lang
# count   200.000000      200.00000     200.000000         200
# unique         NaN            NaN            NaN           5
# top            NaN            NaN            NaN     Chinese
# freq           NaN            NaN            NaN          65
# mean     52.830000       54.98750      77.547500         NaN
# std      12.961912        9.42178       9.165507         NaN
# min      15.000000       20.00000      25.000000         NaN
# 25%      45.000000       48.00000      72.000000         NaN
# 50%      52.500000       56.00000      78.000000         NaN
# 75%      60.000000       62.00000      84.000000         NaN
# max      95.000000       90.00000      94.000000         NaN

# %%
# Q1
# 수학은 85점, 과학은 56점, 영어는 90점

# 1. 동욱이의 수학 점수는 평균보다 높다. (O)
# 2. 동욱이의 영어 점수는 상위 25%에 해당한다. (O)
# 3. 동욱이의 과학 점수는 중간값에 해당한다. (O)
# 4. 동욱이의 과학 점수는 평균보다 낮다. (X) 낮다 -> 높다

# Q2
# Chinese

# Q3
# 77.5

# Q4
# 56

# %% [markdown]
# ## 분산과 표준편차

# %% [markdown]
# **분산과 표준편차**
#
# - 목적: 데이터 값들이 평균을 중심으로 얼마나 퍼져 있는지를 수치로 표현
#
# (1) 편차(deviation): 각 데이터 값과 평균의 차이로 편차의 합은 항상 0이다.
#
# (2) 분산(variance): 편차를 제곱한 값들의 평균으로 제곱을 하는 이유는 편차를 양수화함과 동시에 큰 편차를 더 강조하기 위함이다.
#
# (3) 표준편차(standard deviation): 분산에 제곱근(루트)을 씌운 값으로 루트를 씌우는 이유는 제곱된 단위를 원래 데이터 단위로 되돌리기 위함이다.
#
# **해석**
#
# - 분산/표준편차 작다 → 값들이 평균 근처에 몰려 있다
# - 분산/표준편차 크다 → 값들이 평균에서 멀리 퍼져 있다

# %%
# 라이브러리 불러오기
import pandas as pd

# %%
# 데이터 불러오기
body_df = pd.read_csv("/content/body.csv")
body_df.head()
# Out:
#    height  weight
# 0   188.3    85.8
# 1   176.2    78.0
# 2   175.9    75.6
# 3   181.1    85.1
# 4   182.6    82.3

# %%
# 모분산
import numpy as np
np.var(body_df['height'])
# Out:
# 52.81745615999998

# %%
# 모분산
body_df['height'].var(ddof=0)
# Out:
# 52.81745615999998

# %%
# 표본분산
body_df['height'].var()
# Out:
# 52.92330276553104

# %%
# 모표준편차
import numpy as np
np.std(body_df['height'])
# Out:
# 7.267561913048969

# %%
# 표본표준편차
body_df['height'].std()
# Out:
# 7.274840394505644

# %% [markdown]
# ### 실습) 데이터 분포
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8298)

# %%
# Q4
# 민지네 가족 구성원들의 키를 가지고 모분산을 계산해 보세요.
# 민지의 아버지는 177cm, 민지의 오빠는 183cm, 민지의 어머니는 160cm, 민지는 164cm 입니다.

# %%
import numpy as np

height = np.array([177, 183, 160, 164])
height
# Out:
# array([177, 183, 160, 164])

# %%
# 직접 모분산 계산
((height - height.mean()) ** 2 / 4).sum()
# Out:
# np.float64(87.5)

# %%
# 모분산 계산
height.var()
# Out:
# np.float64(87.5)

# %% [markdown]
# ## 누적값 계산하기

# %% [markdown]
# - `cumsum()`: 누적 합계
# - `cumprod()`: 누적 곱

# %% [markdown]
# (예시)

# %%
# 데이터 불러오기
revenue_df = pd.read_csv("/content/revenue.csv")
revenue_df
# Out:
#     month  revenue
# 0       1     35.8
# 1       2     29.7
# 2       3     36.3
# 3       4     39.6
# 4       5     45.5
# 5       6     49.4
# 6       7    105.1
# 7       8    123.5
# 8       9    155.4
# 9      10    221.8
# 10     11    257.6
# 11     12    265.3

# %%
revenue_df['revenue_cumsum'] = revenue_df['revenue'].cumsum()

# %%
revenue_df
# Out:
#     month  revenue  revenue_cumsum
# 0       1     35.8            35.8
# 1       2     29.7            65.5
# 2       3     36.3           101.8
# 3       4     39.6           141.4
# 4       5     45.5           186.9
# 5       6     49.4           236.3
# 6       7    105.1           341.4
# 7       8    123.5           464.9
# 8       9    155.4           620.3
# 9      10    221.8           842.1
# 10     11    257.6          1099.7
# 11     12    265.3          1365.0

# %%
# 선 그래프
import matplotlib.pyplot as plt

revenue_df.plot(x="month", y="revenue_cumsum")
plt.show()

# %% [markdown]
# (예시)

# %%
# 라이브러리 불러오기
import pandas as pd

# %%
interest_df = pd.read_csv("/content/interest.csv")
interest_df
# Out:
#     year  interest
# 0   2001    0.0546
# 1   2002    0.0471
# 2   2003    0.0415
# 3   2004    0.0375
# 4   2005    0.0357
# 5   2006    0.0436
# 6   2007    0.0501
# 7   2008    0.0567
# 8   2009    0.0323
# 9   2010    0.0318
# 10  2011    0.0369
# 11  2012    0.0343
# 12  2013    0.0270
# 13  2014    0.0242
# 14  2015    0.0172
# 15  2016    0.0147
# 16  2017    0.0151
# 17  2018    0.0184
# 18  2019    0.0174
# 19  2020    0.0104

# %%
interest_df['multiple'] = 1 + interest_df['interest']
interest_df
# Out:
#     year  interest  multiple
# 0   2001    0.0546    1.0546
# 1   2002    0.0471    1.0471
# 2   2003    0.0415    1.0415
# 3   2004    0.0375    1.0375
# 4   2005    0.0357    1.0357
# 5   2006    0.0436    1.0436
# 6   2007    0.0501    1.0501
# 7   2008    0.0567    1.0567
# 8   2009    0.0323    1.0323
# 9   2010    0.0318    1.0318
# 10  2011    0.0369    1.0369
# 11  2012    0.0343    1.0343
# 12  2013    0.0270    1.0270
# 13  2014    0.0242    1.0242
# 14  2015    0.0172    1.0172
# 15  2016    0.0147    1.0147
# 16  2017    0.0151    1.0151
# 17  2018    0.0184    1.0184
# 18  2019    0.0174    1.0174
# 19  2020    0.0104    1.0104

# %%
interest_df['cumulative_multiple'] = interest_df['multiple'].cumprod()
interest_df
# Out:
#     year  interest  multiple  cumulative_multiple
# 0   2001    0.0546    1.0546             1.054600
# 1   2002    0.0471    1.0471             1.104272
# 2   2003    0.0415    1.0415             1.150099
# 3   2004    0.0375    1.0375             1.193228
# 4   2005    0.0357    1.0357             1.235826
# 5   2006    0.0436    1.0436             1.289708
# 6   2007    0.0501    1.0501             1.354322
# 7   2008    0.0567    1.0567             1.431112
# 8   2009    0.0323    1.0323             1.477337
# 9   2010    0.0318    1.0318             1.524317
# 10  2011    0.0369    1.0369             1.580564
# 11  2012    0.0343    1.0343             1.634777
# 12  2013    0.0270    1.0270             1.678916
# 13  2014    0.0242    1.0242             1.719546
# 14  2015    0.0172    1.0172             1.749122
# 15  2016    0.0147    1.0147             1.774834
# 16  2017    0.0151    1.0151             1.801634
# 17  2018    0.0184    1.0184             1.834784
# 18  2019    0.0174    1.0174             1.866710
# 19  2020    0.0104    1.0104             1.886123

# %% [markdown]
# ### 실습) 코드댓, 성공할 수 있을까?
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8300)

# %% [markdown]
# - `day`: 서비스 오픈 후 경과일
# - `register`: 그 날 회원가입한 유저 수
# - `unregister`: 그 날 탈퇴한 유저 수

# %%
# 라이브러리 불러오기
import pandas as pd

# %%
# 데이터 불러오기
user_df = pd.read_csv("/content/user.csv")
user_df
# Out:
#    day  register  unregister
# 0    1        23           0
# 1    2        32           3
# 2    3        75           4
# 3    4        94           5
# 4    5        54           3
# 5    6        40           5
# 6    7        16           3

# %%
user_df['net_user'] = user_df['register'] - user_df['unregister']

# %%
user_df
# Out:
#    day  register  unregister  net_user
# 0    1        23           0        23
# 1    2        32           3        29
# 2    3        75           4        71
# 3    4        94           5        89
# 4    5        54           3        51
# 5    6        40           5        35
# 6    7        16           3        13

# %%
user_df['net_user_cumsum'] = user_df['net_user'].cumsum()

# %%
user_df
# Out:
#    day  register  unregister  net_user  net_user_cumsum
# 0    1        23           0        23               23
# 1    2        32           3        29               52
# 2    3        75           4        71              123
# 3    4        94           5        89              212
# 4    5        54           3        51              263
# 5    6        40           5        35              298
# 6    7        16           3        13              311

# %%
user_df.plot(x="day", y="net_user_cumsum", kind="bar")
plt.show()

# %% [markdown]
# # [2] matplotlib

# %% [markdown]
# ## (1) Boxplot
#
# **상자 그림(Boxplot)**
#
# - 데이터 분포와 이상점을 시각적으로 보여주는 그래프로 여러 그룹 간 분포 비교에 유용하고 IQR을 이용해 이상점을 판별한다.
#
# **상자 그림 해석**
# - 가로선(Line) / 중앙선: 중간값(Median, Q2)
# - 수염(Whiskers): 상자 밖으로 뻗은 선으로, 정상 범위 내의 최소값과 최댓값까지 표시
# - 점(Dots): 정상 범위를 벗어난 이상점 표시
#
# **이상점 판별 기준**
#
# - IQR(사분위 범위) = Q3 - Q1(3사분위수에서 1사분위수를 뺀 값)으로 데이터의 중간 50% 범위를 의미
# - 정상 범위를 계산했을 때, 상한과 하한을 벗어난 값들을 이상점이라고 한다.
#   - 하한 = Q1 - (1.5 × IQR)
#   - 상한 = Q3 + (1.5 × IQR)

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 데이터 불러오기
exam_df = pd.read_csv("/content/exam.csv")
exam_df.head()
# Out:
#    math_score  science_score  english_score second_lang
# 0        45.0           68.0           68.0     Chinese
# 1        80.0           44.0           78.0    Japanese
# 2        37.5           50.0           78.0     Chinese
# 3        57.5           56.0           78.0     Russian
# 4        45.0           68.0           82.0     Chinese

# %%
exam_df['english_score'].describe()
# Out:
# count    200.000000
# mean      77.547500
# std        9.165507
# min       25.000000
# 25%       72.000000
# 50%       78.000000
# 75%       84.000000
# max       94.000000
# Name: english_score, dtype: float64

# %% [markdown]
# **상자 그림 해석**
# - 가로선(Line) / 중앙선: 중간값(Median, Q2)
# - 수염(Whiskers): 상자 밖으로 뻗은 선으로, 정상 범위 내의 최소값과 최댓값까지 표시
# - 점(Dots): 정상 범위를 벗어난 이상점 표시
#
# **이상점 판별 기준**
#
# - IQR(사분위 범위) = Q3 - Q1(3사분위수에서 1사분위수를 뺀 값)으로 데이터의 중간 50% 범위를 의미
# - 정상 범위를 계산했을 때, 상한과 하한을 벗어난 값들을 이상점이라고 한다.
#   - 하한 = Q1 - (1.5 × IQR)
#   - 상한 = Q3 + (1.5 × IQR)

# %%
exam_df['english_score'].plot(kind="box")
plt.show()

# %%
# IQR 기반 이상치 파악
q3 = exam_df['english_score'].quantile(0.75)
q1 = exam_df['english_score'].quantile(0.25)

iqr = q3 - q1

upper_limit = q3 + 1.5*iqr
lower_limit = q1 - 1.5*iqr

# %%
exam_df[exam_df['english_score'] < lower_limit]
# Out:
#      math_score  science_score  english_score second_lang
# 124        40.0           20.0           43.0     Chinese
# 144        40.0           29.0           25.0    Japanese
# 145        18.5           23.0           40.0     Chinese

# %%
# 모든 점수 상자 그림 및 이상치 파악
exam_df.plot(kind="box")
plt.show()

# %%
# 수학 점수, 과학 점수에 대한 이상치 파악
exam_df[['math_score', 'science_score']].plot(kind="box")
plt.show()

# %% [markdown]
# ### 실습) 스타벅스 음료의 칼로리는?
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8290)

# %%
# 데이터 불러오기
starbucks_df = pd.read_csv("/content/starbucks.csv")
starbucks_df.head()
# Out:
#                      category                                      beverage  \
# 0     Classic Espresso Drinks                    Skinny Latte (Any Flavour)
# 1   Signature Espresso Drinks                             Caramel Macchiato
# 2     Classic Espresso Drinks                    Skinny Latte (Any Flavour)
# 3  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 4     Classic Espresso Drinks                                   Caffè Latte
#
#                option  calories  total_carbohydrates(g)  total_fat(g)  \
# 0  Grande Nonfat Milk       120                     160           0.3
# 1  Grande Nonfat Milk       190                     130           1.0
# 2   Short Nonfat Milk        60                      80           0.1
# 3  Grande Nonfat Milk       230                     190           0.2
# 4  Grande Nonfat Milk       130                     150           0.3
#
#    protein(g)  cholesterol(mg)  caffeine(mg)
# 0        12.0               18           150
# 1        11.0               35           150
# 2         6.0                9            75
# 3         4.0               53             0
# 4        13.0               19           150

# %%
starbucks_df['calories'].plot(kind="box")
plt.show()

# %%
starbucks_df.sort_values(by='calories', ascending=False).head(1)
# Out:
#                       category                                       beverage  \
# 217  Signature Espresso Drinks  White Chocolate Mocha (Without Whipped Cream)
#
#       option  calories  total_carbohydrates(g)  total_fat(g)  protein(g)  \
# 217  2% Milk       510                     330          15.0        19.0
#
#      cholesterol(mg)  caffeine(mg)
# 217               77           150

# %% [markdown]
# ## (2) Histogram
#
# **히스토그램**
#
# - 수치형 데이터를 구간별로 묶어 분포 형태와 패턴을 직관적으로 파악할 때 유용하고, 값을 일정한 구간(bin)으로 나누어, 각 구간에 속하는 데이터 개수를 막대 높이로 표시
#
# **데이터 유형**
#
# - 이산형(discrete): 개수, 사건 횟수 등
# - 연속형(continuous): 키, 몸무게, 온도 등
#
# **언제 사용?**
#
# (1) 데이터의 전반적인 분포 파악 : 값들이 어떤 범위에 몰려 있는지, 퍼져 있는지 확인 가능
#
# (2) 중심 경향과 변동성 확인 : 대략적인 평균, 퍼짐 정도, 치우침(왜도) 파악 가능
#
# (3) 이상치 탐색 전 단계 : 특정 구간에 예상보다 적거나 많은 데이터가 있을 경우 이상치 가능성 확인
#
# (4) 데이터 비교 : 두 개 이상의 집단이 비슷한 분포를 가지는지 비교할 때
#
# (5) 정규성 판단 : 데이터가 종 모양(정규분포)에 가까운지 시각적으로 확인

# %%
# 데이터 불러오기
body_df = pd.read_csv("/content/body.csv")
body_df.head()
# Out:
#    height  weight
# 0   188.3    85.8
# 1   176.2    78.0
# 2   175.9    75.6
# 3   181.1    85.1
# 4   182.6    82.3

# %%
body_df.shape
# Out:
# (500, 2)

# %% [markdown]
# - 히스토그램에서는 `bins`를 따로 설정하지 않으면, 기본적으로 구간을 10개로 나눈다.
# - 히스토그램의 목적은 구간별로 데이터가 얼마나 많은지 확인하는 것이므로 상황에 맞게 적당한 구간 수를 정하는 것이 중요하다.

# %%
body_df['height'].plot(kind="hist", bins=20)
plt.show()

# %% [markdown]
# ### 실습) 중고차 데이터 분석I
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8292)

# %%
# 데이터 불러오기
car_df = pd.read_csv("/content/car.csv")
car_df.head()
# Out:
#     manufacturer   category fuel_type  engine_volume  mileage  price
# 0        HYUNDAI       Jeep    Petrol            2.0    36800  36065
# 1         TOYOTA      Sedan    Petrol            2.5   107000  15053
# 2         NISSAN       Jeep    Petrol            1.6   108222   7527
# 3            BMW       Jeep    Diesel            3.0    18000  15681
# 4  MERCEDES-BENZ  Hatchback    Petrol            1.7   160000  13485

# %%
# 범주의 종류
car_df['manufacturer'].unique()
# Out:
# array(['HYUNDAI', 'TOYOTA', 'NISSAN', 'BMW', 'MERCEDES-BENZ',
#        'VOLKSWAGEN', 'CHEVROLET', 'FORD', 'HONDA', 'LEXUS', 'AUDI'],
#       dtype=object)

# %%
car_df[car_df['manufacturer'] == 'HYUNDAI']['price'].plot(kind="hist", bins=10)
plt.show()

# %% [markdown]
# ## (3) PDF와 KDE Plot

# %% [markdown]
# **확률 밀도 함수(Probability Density Function, PDF)**
#
# - 모집단 전체를 표현하는 이상적 개념으로 연속형 데이터의 이론적 분포를 비중(확률)으로 표현하고, 특정 값 자체의 확률은 0, 그래프 전체 넓이는 1이다.
#
# **KDE Plot**
#
# - KDE Plot(Kernel Density Estimation)
#
# - 표본 데이터를 바탕으로 확률 밀도 함수를 추정하고, 연속형 데이터의 분포를 부드럽게 표현

# %%
# 데이터 불러오기
body_df = pd.read_csv("/content/body.csv")
body_df.head()
# Out:
#    height  weight
# 0   188.3    85.8
# 1   176.2    78.0
# 2   175.9    75.6
# 3   181.1    85.1
# 4   182.6    82.3

# %%
body_df['height'].plot(kind="kde", bw_method=0.1)  # bw_method(bandwidth method) : 더 세세하게 표현할 때 사용
plt.show()

# %%
body_df['height'].plot(kind="kde", bw_method=2)  # bw_method(bandwidth method) : 더 세세하게 표현할 때 사용
plt.show()

# %% [markdown]
# ### 실습) 중고차 데이터 분석 II
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8352)

# %%
# 데이터 불러오기
car_df = pd.read_csv("/content/car.csv")
car_df.head()
# Out:
#     manufacturer   category fuel_type  engine_volume  mileage  price
# 0        HYUNDAI       Jeep    Petrol            2.0    36800  36065
# 1         TOYOTA      Sedan    Petrol            2.5   107000  15053
# 2         NISSAN       Jeep    Petrol            1.6   108222   7527
# 3            BMW       Jeep    Diesel            3.0    18000  15681
# 4  MERCEDES-BENZ  Hatchback    Petrol            1.7   160000  13485

# %%
# Q1. 어떤 제조사의 중고차 가격 정보를 가지고 그린 것인지

# %%
# 범주의 종류의 개수
car_df['manufacturer'].nunique()
# Out:
# 11

# %%
# 범주의 종류
car_df['manufacturer'].unique()
# Out:
# array(['HYUNDAI', 'TOYOTA', 'NISSAN', 'BMW', 'MERCEDES-BENZ',
#        'VOLKSWAGEN', 'CHEVROLET', 'FORD', 'HONDA', 'LEXUS', 'AUDI'],
#       dtype=object)

# %%
# BMW의 가격 분포 히스토그램
car_df[car_df['manufacturer'] == 'BMW']['price'].plot(kind="hist")
plt.show()

# %%
# HYUNDAI의 가격 분포 히스토그램
car_df[car_df['manufacturer'] == 'HYUNDAI']['price'].plot(kind="hist")
plt.show()

# %%
# LEXUS의 가격 분포 히스토그램
car_df[car_df['manufacturer'] == 'LEXUS']['price'].plot(kind="hist")
plt.show()

# %%
# VOLKSWAGEN의 가격 분포 히스토그램
car_df[car_df['manufacturer'] == 'VOLKSWAGEN']['price'].plot(kind="hist")
plt.show()

# %%
# Q3. 아우디(AUDI)인 중고차 중에서 가격이 다른 차보다 유독 저렴하거나 비싼 이상점
car_df[car_df['manufacturer'] == 'AUDI']['price'].plot(kind="box")
plt.show()

# %%
# Q4. 중고차의 주행 거리(mileage)의 1사분위수와 3사분위수

# %%
q1 = car_df['mileage'].quantile(0.25)
q3 = car_df['mileage'].quantile(0.75)

q1, q3
# Out:
# (np.float64(70000.0), np.float64(177932.0))

# %%
car_df['mileage'].describe()
# Out:
# count     12019.000000
# mean     131629.232798
# std       85761.569484
# min           0.000000
# 25%       70000.000000
# 50%      120950.000000
# 75%      177932.000000
# max      498815.000000
# Name: mileage, dtype: float64

# %% [markdown]
# # [3] seaborn
#
# - **seaborn** : matplotlib 기반 통계 시각화 라이브러리
#
# - **장점**
#   - 코드가 간결하고, 기본 스타일이 세련되어 빠르게 가독성 높은 그래프 생성
#
# - **matplotlib과 비교**
#   - matplotlib : 원하는 대로 커스터마이징 가능
#   - seaborn : 기본 그래프가 깔끔하고 통계 시각화에 특화

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.12/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# | 변수명        | 설명 |
# |---------------|------------------------------------------------|
# | month         | 월|
# | day           | 일|
# | quarter       | 분기|
# | day_of_week   | 요일 (0=월요일, 6=일요일) |
# | workingday    | 근무일 여부 (1=평일이면서 휴일 아님, 0=주말/휴일) |
# | holiday       | 공휴일 여부 (1=공휴일, 0=평일/주말) |
# | temperature   | 기온 (섭씨) |
# | humidity      | 습도 (0~100) |
# | windspeed     | 풍속 (m/s) |
# | registered    | 등록된 사용자(회원)의 이용 건수 |
# | casual        | 비회원(일시 사용자)의 이용 건수 |
# | total         | 전체 이용 건수 (`registered + casual`) |

# %%
# 데이터 불러오기
bike_df = pd.read_csv("/content/bike.csv")
bike_df.head()
# Out:
#    month  day quarter day_of_week  workingday  holiday  temperature  humidity  \
# 0      1    1      1Q         SUN           0        0         21.4        72
# 1      1    2      1Q         MON           0        1         15.0        44
# 2      1    3      1Q         TUE           1        0          7.6        39
# 3      1    4      1Q         WED           1        0          0.4        35
# 4      1    5      1Q         THU           1        0         14.2        49
#
#    windspeed  registered  casual  total
# 0         12        1608     686   2294
# 1         19        1707     244   1951
# 2         23        2147      89   2236
# 3         11        2273      95   2368
# 4          6        3132     140   3272

# %% [markdown]
# ## set_theme() : 그래프 커스터마이징

# %% [markdown]
# **set_theme() : 그래프 커스터마이징하기**
#
# - style에 dark, whitegrid, ticks
# - palette에 pastel, muted, bright, dark, colorblind([링크](https://seaborn.pydata.org/tutorial/color_palettes.html))

# %%
# 월별 자전거 총 대여량
sns.set_theme(rc={'figure.figsize': (8, 4)}, style="white")
sns.barplot(data=bike_df, x="month", y="total", errorbar=None, palette="pastel")
plt.show()
# Out:
# /tmp/ipython-input-3125232230.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bike_df, x="month", y="total", errorbar=None, palette="pastel")

# %%
# 월별 근무일별 자전거 총 대여량
sns.set_theme(rc={'figure.figsize': (8, 4)}, style="white")
sns.barplot(data=bike_df, x="month", y="total", errorbar=None, hue="workingday")
plt.show()

# %% [markdown]
# (회원의 자전거 대여량)

# %%
# 월별 근무일별 회원의 자전거 대여량
sns.set_theme(rc={'figure.figsize': (8, 4)}, style="white")
sns.barplot(data=bike_df, x="month", y="registered", errorbar=None, hue="workingday")
plt.show()

# %% [markdown]
# (비회원의 자전거 대여량)

# %%
# 월별 근무일별 비회원의 자전거 대여량
sns.set_theme(rc={'figure.figsize': (8, 4)}, style="white")
sns.barplot(data=bike_df, x="month", y="casual", errorbar=None, hue="workingday")
plt.show()

# %% [markdown]
# (회원의 월별 자전거 대여량 추이)

# %%
# 월별 근무일별 회원의 자전거 대여량
sns.set_theme(rc={'figure.figsize': (8, 4)}, style="white")
sns.lineplot(data=bike_df, x="month", y="registered", errorbar=None, hue="workingday")
plt.show()

# %% [markdown]
# (비회원의 월별 자전거 대여량 추이)

# %%
# 월별 근무일별 비회원의 자전거 대여량
sns.set_theme(rc={'figure.figsize': (8, 4)}, style="white")
sns.lineplot(data=bike_df, x="month", y="casual", errorbar=None, hue="workingday")
plt.show()

# %% [markdown]
# ### 실습) 공유 자전거 데이터 더 살펴보기 I
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8303)

# %%
# 분기별 근무일별 회원의 자전거 대여량
sns.set_theme(rc={'figure.figsize': (8, 4)}, style="white")
sns.barplot(data=bike_df, x="quarter", y="registered", errorbar=None, hue="workingday")
plt.show()

# %% [markdown]
# ## (1) stripplot

# %% [markdown]
# - **정의** : strip은 가느다란 조각이라는 뜻을 가지고 있고, 범주형 데이터의 분포를 점(개별 관측치)으로 표현하는 그래프
#
# - **특징**
#   - 각 범주(category)별 데이터 포인트 시각화
#   - 값의 분포와 밀집 정도를 직관적으로 확인 가능
#   - `jitter=True` 옵션을 사용하여 데이터 포인트를 수평으로 흩뿌려 겹침 방지
#   - `hue` 인자로 그룹을 색상별로 구분 가능
#
# - **사용 상황**
#   - 소규모 데이터셋 분포 확인
#   - 범주별 데이터 비교

# %% [markdown]
# - 월별로 데이터가 어떻게 분포되어 있는지 확인 가능하다.
# - 여름, 가을에는 데이터가 비교적 높은 곳에 분포하고, 겨울에는 비교적 낮은 곳에 분포하고 있음을 알 수 있다.

# %%
# 월별 자전거 총 대여량
sns.stripplot(data=bike_df, x="month", y="total")
plt.show()

# %%
# 월별 근무일별 자전거 총 대여량
sns.stripplot(data=bike_df, x="month", y="total", hue="workingday")
plt.show()

# %% [markdown]
# ### 실습) 공유 자전거 데이터 더 살펴보기 II
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8304?mediumTypedId=U2tpbGxQYXRoOjYyYjJjMjAyNzAwOWM1N2E1MjQwMThmYQ%3D%3D)

# %%
# 월별 기온
sns.set_theme(rc={'figure.figsize': (10, 5)}, style='white')
sns.stripplot(data=bike_df, x="month", y="temperature")
plt.show()

# %% [markdown]
# ## (2) swarmplot

# %% [markdown]
# - **정의** : 범주형 데이터의 분포를 점으로 표현하며, **데이터 포인트가 겹치지 않도록** 배치하는 그래프
# - **특징**
#   - `stripplot`과 유사하지만 점이 겹치지 않게 자동 조정
#   - 데이터의 분포와 밀도를 직관적으로 확인 가능
#   - 값의 수가 많으면 표시가 복잡해질 수 있음
#   - `hue` 인자로 색상 그룹화 가능
# - **사용 상황**
#   - 범주형 데이터의 분포를 더 깔끔하게 보고 싶을 때
#   - `stripplot`의 겹침 문제를 해결하고자 할 때

# %% [markdown]
# swarm은 떼, 무리라는 의미로 값들이 몰려있는 경우 옆으로 쌓여서 stripplot보다 보기가 편함

# %%
# 월별 근무일별 자전거 총 대여량
sns.swarmplot(data=bike_df, x="month", y="total", hue="workingday")
plt.show()

# %% [markdown]
# ## (3) Box Plot

# %% [markdown]
# - **정의** : 데이터의 분포를 사분위수(Q1, Q3)와 중앙값(median)으로 표현하는 그래프
#
# - **특징**
#   - 박스(Box): Q1 ~ Q3(IQR, interquartile range)
#   - 선(Whisker): 데이터의 전체 범위(보통 Q1-1.5*IQR ~ Q3+1.5*IQR)
#   - 점(Point): 이상치(outlier)
#   - 데이터의 중심, 분산, 이상치를 한눈에 파악 가능
#
# - **사용 상황**
#   - 그룹별 데이터 분포 비교
#   - 이상치 탐지 및 데이터 분포 요약

# %% [markdown]
# - 등록된 사용자(회원)들이 주말에는 이용 대수가 적음을 알 수 있다.

# %%
bike_df.head()
# Out:
#    month  day quarter day_of_week  workingday  holiday  temperature  humidity  \
# 0      1    1      1Q         SUN           0        0         21.4        72
# 1      1    2      1Q         MON           0        1         15.0        44
# 2      1    3      1Q         TUE           1        0          7.6        39
# 3      1    4      1Q         WED           1        0          0.4        35
# 4      1    5      1Q         THU           1        0         14.2        49
#
#    windspeed  registered  casual  total
# 0         12        1608     686   2294
# 1         19        1707     244   1951
# 2         23        2147      89   2236
# 3         11        2273      95   2368
# 4          6        3132     140   3272

# %%
# 요일별 회원의 자전거 대여량 분포
sns.boxplot(data=bike_df, x="day_of_week", y="registered")
plt.show()

# %%
# 요일별 회원의 자전거 대여량 분포
sns.boxplot(data=bike_df, x="day_of_week", y="registered", order=['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN'])
plt.show()

# %% [markdown]
# ## (4) Violin Plot

# %% [markdown]
# - **정의** : `boxplot`에 밀도 분포(KDE)를 더한 그래프
# - **특징**
#   - 중앙값과 사분위수는 boxplot처럼 표현
#   - 데이터 분포 모양을 KDE 플롯을 양옆으로 붙여 놓은 바이올린 형태로 표시
#   - 분포의 대칭성, 치우침 등 여부를 파악 가능
#   - `hue` 옵션으로 그룹 비교 가능
# - **사용 상황**
#   - 데이터의 분포 형태를 더 직관적으로 보고 싶을 때
#   - boxplot만으로는 파악하기 어려운 분포 특성을 설명할 때

# %%
sns.violinplot(data=bike_df, x="day_of_week", y="registered", order=['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN'])
plt.show()

# %% [markdown]
# ### 실습) 이코노미와 비즈니스
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8307?mediumTypedId=U2tpbGxQYXRoOjYyYjJjMjAyNzAwOWM1N2E1MjQwMThmYQ%3D%3D)

# %%
# 데이터 불러오기
flight_df = pd.read_csv("/content/flight.csv")
flight_df.head()
# Out:
#      airline  flight source_city departure_time stops arrival_time  \
# 0   GO_FIRST  G8-803   Bangalore        Evening   one   Late_Night
# 1    Vistara  UK-827      Mumbai          Night   one      Morning
# 2    Vistara  UK-850   Bangalore        Evening   one        Night
# 3   SpiceJet  SG-678     Chennai  Early_Morning   one      Morning
# 4  Air_India  AI-660      Mumbai        Evening   one      Morning
#
#   destination_city     class  duration  days_left  price
# 0           Mumbai   Economy      7.17         25     70
# 1            Delhi   Economy     12.75         43     66
# 2        Hyderabad  Business     25.00          7    513
# 3            Delhi   Economy     27.17         49     73
# 4          Chennai   Economy     14.92          7    124

# %%
# 범주의 종류의 개수
flight_df['class'].nunique()
# Out:
# 2

# %%
# 범주의 종류
flight_df['class'].unique()
# Out:
# array(['Economy', 'Business'], dtype=object)

# %%
sns.violinplot(data=flight_df, x="class", y="price")
plt.show()

# %% [markdown]
# ## (5) Histogram

# %% [markdown]
# - **정의** : 연속형 데이터를 구간(bin)으로 나누어 각 구간에 속하는 데이터의 개수를 막대그래프로 표현
# - **특징**
#   - 데이터의 분포 형태(대칭, 치우침, 다봉형 등)를 직관적으로 확인
#   - `bins` 매개변수로 구간 개수 조절 가능
#   - `kde`(밀도 곡선)와 함께 그리면 분포를 더 부드럽게 파악 가능
# - **사용 상황**
#   - 데이터가 어떤 범위에 많이 분포하는지 확인
#   - 이상치(outlier) 탐지
#   - 분포가 정규분포에 가까운지 확인

# %%
bike_df.head(1)
# Out:
#    month  day quarter day_of_week  workingday  holiday  temperature  humidity  \
# 0      1    1      1Q         SUN           0        0         21.4        72
#
#    windspeed  registered  casual  total
# 0         12        1608     686   2294

# %%
# 회원의 자전거 대여량 분포
sns.histplot(data=bike_df, x="registered", bins=10)
plt.show()

# %%
# 회원의 자전거 대여량 분포
sns.histplot(data=bike_df, y="registered", bins=10)
plt.show()

# %%
# 근무일별 회원의 자전거 대여량 분포
sns.histplot(data=bike_df, x="registered", hue="workingday")
plt.show()

# %%
# 근무일별 비회원의 자전거 대여량 분포
sns.histplot(data=bike_df, x="casual", hue="workingday")
plt.show()

# %%
# 근무일별 회원의 자전거 대여량 분포
sns.histplot(data=bike_df, x="registered", hue="workingday", multiple="stack")
plt.show()

# %% [markdown]
# ### 실습) 흡연여부와 보험금
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8308?mediumTypedId=U2tpbGxQYXRoOjYyYjJjMjAyNzAwOWM1N2E1MjQwMThmYQ%3D%3D)

# %%
# 데이터 불러오기
insurance_df = pd.read_csv("/content/insurance_charge.csv")
insurance_df.head()
# Out:
#    age     sex   bmi smoking  children  charge
# 0   28  female  28.6      no         1    4318
# 1   28    male  27.0      no         2    4435
# 2   57    male  24.7      no         1   12002
# 3   25    male  35.6      no         0    2534
# 4   30    male  32.9      no         5    6380

# %%
sns.histplot(data=insurance_df, x="charge", hue="smoking", multiple="stack")
plt.show()

# %% [markdown]
# ## (6) KDE Plot

# %% [markdown]
# - **정의** : 커널 밀도 추정(Kernel Density Estimation, KDE)을 이용해 **데이터의 분포를 연속적인 곡선**으로 표현한 그래프
# - **특징**
#   - 히스토그램과 달리 매끄러운 분포 곡선 제공
#   - 데이터의 치우침(skewness), 대칭성, 다중 봉우리 여부 확인 가능
#   - `fill=True` 옵션 → 곡선 아래 영역 색칠 가능
#   - `hue` 인자로 그룹별 분포 비교 가능
# - **사용 상황**
#   - 데이터의 분포 패턴을 직관적으로 파악
#   - 여러 집단의 분포 비교

# %%
sns.kdeplot(data=bike_df, x="registered")
plt.show()

# %%
sns.kdeplot(data=bike_df, x="registered", fill=True)
plt.show()

# %%
sns.kdeplot(data=bike_df, x="registered", fill=True, bw_method=0.1)  # bw_method(bandwidth method) : 세세하게 표현
plt.show()

# %% [markdown]
# ## (7) Scatter Plot

# %% [markdown]
# - **정의** : 두 연속형 변수의 관계를 **좌표평면에 점으로 표시**하는 그래프
# - **특징**
#   - X축과 Y축 각각 하나의 변수 대응
#   - 변수 간 상관관계(양/음, 강도) 시각화
#   - 이상치(outlier) 탐지에 유용
#   - `hue`, `style`, `size`로 추가 변수 시각화 가능
# - **사용 상황**
#   - 두 변수 사이의 관계 분석
#   - 데이터의 분산 정도 및 패턴 확인

# %% [markdown]
# - 기온이 낮을 때는 자전거 대여 건수가 낮고, 기온이 높을 때는 자전거 대여 건수도 높음을 알 수 있다.

# %%
sns.set_theme(rc={'figure.figsize': (6, 6)}, style="white")
sns.scatterplot(data=bike_df, x="temperature", y="total")
plt.show()

# %%
bike_df[['temperature', 'total']].corr()
# Out:
#              temperature    total
# temperature      1.00000  0.64386
# total            0.64386  1.00000

# %%
sns.set_theme(rc={'figure.figsize': (6, 6)}, style="white")
sns.scatterplot(data=bike_df, x="temperature", y="total")
plt.xticks(range(0, 51, 5))
plt.show()

# %% [markdown]
# ## (8) Regplot

# %% [markdown]
# - **정의** : 두 변수 간의 관계를 산점도와 함께 회귀선(Regression Line)으로 표현하는 그래프
#
# - **특징**
#   - 산점도 + 선형 회귀선 표시
#   - 데이터 간의 선형성 여부 확인 가능
#   - 이상치의 영향을 시각적으로 파악 가능
#
# - **사용 상황**
#   - 두 변수의 상관관계 분석
#   - 회귀선을 통해 추세선 확인
#   - 선형 회귀 기반 예측 가능성 탐색
#
# **CI(Confidence Interval)**
# - `ci` 옵션으로 신뢰구간(Confidence Interval) 시각화
#
# - **기능** : 회귀선 주변에 표시되는 신뢰구간(Confidence Interval)의 범위를 지정
#
# - **사용법**
#   - `ci=95` : 95% 신뢰구간 (기본값) : 같은 데이터로 여러 번 샘플링했을 때, 95%의 확률로 실제 회귀선이 이 구간 안에 포함됨을 의미
#   - `ci=None` : 신뢰구간 표시하지 않음
#   - `ci=숫자` : 원하는 신뢰수준 적용 (예: 68, 90)

# %% [markdown]
# - 기온이 높아질수록 자전거량이 증가함을 확인할 수 있다.

# %%
sns.regplot(data=bike_df, x="temperature", y="total")
plt.show()

# %%
bike_df[['temperature', 'total']].corr()
# Out:
#              temperature    total
# temperature      1.00000  0.64386
# total            0.64386  1.00000

# %% [markdown]
# - 풍속이 세질수록 자전거 대여량이 낮아지는 것을 확인할 수 있다.

# %%
sns.regplot(data=bike_df, x="windspeed", y="total")
plt.show()

# %%
bike_df[['windspeed', 'total']].corr()
# Out:
#            windspeed     total
# windspeed   1.000000 -0.189995
# total      -0.189995  1.000000

# %% [markdown]
# - 습도와 자전거 대여량은 거의 상관관계가 존재하지 않음을 확인할 수 있다.

# %%
sns.regplot(data=bike_df, x="humidity", y="total")
plt.show()

# %%
bike_df[['humidity', 'total']].corr()
# Out:
#           humidity     total
# humidity  1.000000 -0.067814
# total    -0.067814  1.000000

# %% [markdown]
# ### 실습) 비싼 와인이 더 맛있을까?
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8310?mediumTypedId=U2tpbGxQYXRoOjYyYjJjMjAyNzAwOWM1N2E1MjQwMThmYQ%3D%3D)

# %%
# 데이터 불러오기
wine_df = pd.read_csv("/content/wine.csv")
wine_df.head()
# Out:
#                                                title country    province  \
# 0  L'Ecole No. 41 2016 Chardonnay (Columbia Valle...      US  Washington
# 1       Hanging Vine 2007 Parcel 4 Chardonnay (Lodi)      US  California
# 2            Irony 2008 Pinot Noir (Monterey County)      US  California
# 3  Sonoma-Cutrer 2008 Russian River Ranches Chard...      US  California
# 4   Gibbs 2013 Money Road Vineyard Merlot (Oakville)      US  California
#
#                region_1         region_2          winery  points  price
# 0  Columbia Valley (WA)  Columbia Valley  L'Ecole No. 41    91.5   22.8
# 1                  Lodi   Central Valley    Hanging Vine    82.3   12.8
# 2       Monterey County    Central Coast           Irony    85.4   15.6
# 3          Sonoma Coast           Sonoma   Sonoma-Cutrer    92.8   23.3
# 4              Oakville             Napa           Gibbs    85.0   24.7

# %%
sns.regplot(data=wine_df, x="price", y="points")
plt.show()

# %% [markdown]
# ## (9) Correlation Heatmap

# %% [markdown]
# - **산점도 (Scatter Plot)** : 두 변수 간의 관계를 점으로 표현
# - **상관계수 (Correlation Coefficient)**
#   - 피어슨(Pearson) 상관계수: -1 ~ 1 범위
#   - `= 0` → 두 변수 간 상관 없음
#   - `> 0` → 양의 상관관계(한 변수가 커질수록 다른 변수도 커짐)
#   - `< 0` → 음의 상관관계(한 변수가 커질수록 다른 변수는 작아짐)
#   - **상관관계의 강도**: 절댓값이 1에 가까울수록 강함

# %%
bike_df.head()
# Out:
#    month  day quarter day_of_week  workingday  holiday  temperature  humidity  \
# 0      1    1      1Q         SUN           0        0         21.4        72
# 1      1    2      1Q         MON           0        1         15.0        44
# 2      1    3      1Q         TUE           1        0          7.6        39
# 3      1    4      1Q         WED           1        0          0.4        35
# 4      1    5      1Q         THU           1        0         14.2        49
#
#    windspeed  registered  casual  total
# 0         12        1608     686   2294
# 1         19        1707     244   1951
# 2         23        2147      89   2236
# 3         11        2273      95   2368
# 4          6        3132     140   3272

# %% [markdown]
# - `numeric_only=True` : 수치형 데이터에 대해서 상관계수

# %%
bike_df.corr(numeric_only=True)
# Out:
#                 month       day  workingday   holiday  temperature  humidity  \
# month        1.000000  0.006443   -0.007513  0.006258     0.128435  0.191763
# day          0.006443  1.000000    0.022520 -0.031464     0.006938  0.092935
# workingday  -0.007513  0.022520    1.000000 -0.258418     0.029387  0.043649
# holiday      0.006258 -0.031464   -0.258418  1.000000    -0.019713 -0.023121
# temperature  0.128435  0.006938    0.029387 -0.019713     1.000000  0.087400
# humidity     0.191763  0.092935    0.043649 -0.023121     0.087400  1.000000
# windspeed   -0.043407  0.024777   -0.072115  0.057260    -0.114972 -0.221569
# registered   0.281855 -0.055827    0.437003 -0.164190     0.554088 -0.049545
# casual       0.099117 -0.019697   -0.539919  0.029720     0.477538 -0.066836
# total        0.266502 -0.052814    0.118884 -0.118134     0.643860 -0.067814
#
#              windspeed  registered    casual     total
# month        -0.043407    0.281855  0.099117  0.266502
# day           0.024777   -0.055827 -0.019697 -0.052814
# workingday   -0.072115    0.437003 -0.539919  0.118884
# holiday       0.057260   -0.164190  0.029720 -0.118134
# temperature  -0.114972    0.554088  0.477538  0.643860
# humidity     -0.221569   -0.049545 -0.066836 -0.067814
# windspeed     1.000000   -0.182959 -0.104406 -0.189995
# registered   -0.182959    1.000000  0.274984  0.912994
# casual       -0.104406    0.274984  1.000000  0.643305
# total        -0.189995    0.912994  0.643305  1.000000

# %%
# 전체 자전거 대여량과 다른 변수들 간의 상관관계
bike_df.corr(numeric_only=True)['total'].sort_values(ascending=False)
# Out:
# total          1.000000
# registered     0.912994
# temperature    0.643860
# casual         0.643305
# month          0.266502
# workingday     0.118884
# day           -0.052814
# humidity      -0.067814
# holiday       -0.118134
# windspeed     -0.189995
# Name: total, dtype: float64

# %%
sns.set_theme(rc={'figure.figsize': (8, 8)})
sns.heatmap(bike_df.corr(numeric_only=True), annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# ### 실습) 보험료 데이터 분석하기
#
# [링크](https://www.codeit.kr/topics/statistics-and-visualization/lessons/8311?mediumTypedId=U2tpbGxQYXRoOjYyYjJjMjAyNzAwOWM1N2E1MjQwMThmYQ%3D%3D)

# %%
# 데이터 불러오기
premium_df = pd.read_csv("/content/insurance_premium.csv")
premium_df.head()
# Out:
#    age  diabetes  blood_pressure_problems  any_chronic_diseases  allergy  \
# 0   45         0                        0                     0        0
# 1   60         1                        1                     0        0
# 2   36         1                        1                     1        0
# 3   52         1                        1                     1        0
# 4   38         0                        0                     1        0
#
#    number_of_major_surgeries  premium_price
# 0                          0          25000
# 1                          0          39000
# 2                          1          26000
# 3                          2          36000
# 4                          1          28000

# %%
sns.set_theme(rc={'figure.figsize': (6, 6)})
sns.heatmap(premium_df.corr(), annot=True, fmt='.2f')
plt.show()
